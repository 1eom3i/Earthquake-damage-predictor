# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.optim import SGD
import torch.utils.data as Data
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# # **Read the Data**

# %%
train_y = pd.read_csv("train_labels.csv", index_col='building_id')
train_x = pd.read_csv("train_values.csv", index_col='building_id')
test_x = pd.read_csv("test_values.csv", index_col='building_id')

# %% [markdown]
# # **Feature Engineering- ANN**

# %%
geo1 = np.array(pd.get_dummies(pd.concat([train_x["geo_level_1_id"], test_x["geo_level_1_id"]])))
geo2 = np.array(pd.get_dummies(pd.concat([train_x["geo_level_2_id"], test_x["geo_level_2_id"]])))
geo3 = pd.concat([train_x["geo_level_3_id"], test_x["geo_level_3_id"]]).to_numpy()

# %%
geo1 = torch.tensor(geo1, dtype = torch.float)
geo2 = torch.tensor(geo2, dtype = torch.float)
geo3 = torch.tensor(geo3, dtype = torch.long)

# %%
geo1_train, geo1_valid, geo2_train, geo2_valid, geo3_train, geo3_valid = train_test_split(geo1, geo2, geo3, test_size = 0.2)

# %%
train_dataset = Data.TensorDataset(geo1_train, geo2_train, geo3_train)
train_loader = Data.DataLoader(dataset = train_dataset, batch_size = 64, shuffle = True)

# %% [markdown]
# **Training**

# %%
class EmbedNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.embed = nn.Embedding(12568, 16)
        self.layer1 = nn.Sequential(nn.Linear(16, 31), nn.Sigmoid())
        self.layer2 = nn.Sequential(nn.Linear(16, 1418), nn.Sigmoid())
        
    def forward(self, inputValue):
        mid = self.embed(inputValue)
        out1 = self.layer1(mid)
        out2 = self.layer2(mid)
        return out1, out2
    
    def get_feature(self, inputValue):
        return self.embed(inputValue.long())

# %%
model = EmbedNet()
loss_func = nn.BCEWithLogitsLoss() # binary CrossEntropy
optimizer = torch.optim.Adam(model.parameters(), lr=0.1) #ADAM

# %%
training_loss_hist = []
validation_loss_hist = []

# %%
for epoch in range(10):
    epoch_loss = []
    
    model.train()
    for batch_geo1, batch_geo2, batch_geo3 in tqdm(train_loader):
        output1, output2 = model(batch_geo3)
        loss1 = loss_func(output1, batch_geo1)
        loss2 = loss_func(output2, batch_geo2)
        loss = loss1 + loss2
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_loss.append(float(loss))
        
    model.eval()
    y_pred1, y_pred2 = model(geo3_valid)
    
    acc1 = (torch.argmax(y_pred1, 1) == torch.argmax(geo1_valid, 1)).float().mean()
    acc2 = (torch.argmax(y_pred2, 1) == torch.argmax(geo2_valid, 1)).float().mean()
    print(f'epoch: {epoch} acc1: {acc1}, acc2: {acc2}')
    
    training_loss_hist.append(np.mean(epoch_loss))
    validation_loss_hist.append(float(loss_func(y_pred1, geo1_valid) + loss_func(y_pred2, geo2_valid)))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:27<00:00, 157.28it/s]
# epoch: 0 acc1: 0.039240796118974686, acc2: 1.4389731404662598e-05
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:27<00:00, 156.15it/s]
# epoch: 1 acc1: 0.05745819956064224, acc2: 0.0007482660585083067
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:28<00:00, 154.71it/s]
# epoch: 2 acc1: 0.07484099268913269, acc2: 0.00047486115363426507
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:29<00:00, 147.60it/s]
# epoch: 3 acc1: 0.07973350584506989, acc2: 0.0005468098097480834
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:30<00:00, 144.61it/s]
# epoch: 4 acc1: 0.05106915533542633, acc2: 0.0005468098097480834
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:30<00:00, 140.40it/s]
# epoch: 5 acc1: 0.05098281800746918, acc2: 0.0005468098097480834
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:30<00:00, 144.33it/s]
# epoch: 6 acc1: 0.05158718675374985, acc2: 0.0005611995002254844
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:31<00:00, 139.44it/s]
# epoch: 7 acc1: 0.05301177129149437, acc2: 0.0006187584367580712
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:30<00:00, 141.94it/s]
# epoch: 8 acc1: 0.013555127196013927, acc2: 0.0006187584367580712
# 100%|█████████████████████████████████████████████████████████████████████████████| 4344/4344 [00:30<00:00, 142.91it/s]
# epoch: 9 acc1: 0.01352634746581316, acc2: 0.0007626557489857078

# %%
torch.save(model, "embed3")

# %%
embedModel = torch.load("embed3")
embedModel.eval()
# Out:
# EmbedNet(
#   (embed): Embedding(12568, 16)
#   (layer1): Sequential(
#     (0): Linear(in_features=16, out_features=31, bias=True)
#     (1): Sigmoid()
#   )
#   (layer2): Sequential(
#     (0): Linear(in_features=16, out_features=1418, bias=True)
#     (1): Sigmoid()
#   )
# )

# %% [markdown]
# Add new features to training dataset

# %%
geo3 = train_x["geo_level_3_id"].to_numpy()
geo3 = torch.tensor(geo3, dtype = torch.long)
feature = embedModel.get_feature(geo3).detach().numpy()

# %%
a = pd.DataFrame(feature)
a.columns = ['geo_feat1',
       'geo_feat2', 'geo_feat3', 'geo_feat4', 'geo_feat5', 'geo_feat6',
       'geo_feat7', 'geo_feat8', 'geo_feat9', 'geo_feat10', 'geo_feat11',
       'geo_feat12', 'geo_feat13', 'geo_feat14', 'geo_feat15', 'geo_feat16']
a
# Out:
#         geo_feat1  geo_feat2  geo_feat3  geo_feat4  geo_feat5  geo_feat6  \
# 0        1.859609  -2.464615   2.333843  -2.766396  -2.544667   0.006577
# 1        1.256276  -1.346431   1.864876  -1.247013  -1.164752  -0.183126
# 2        3.349025  -2.026550   2.095108  -0.456444  -3.202587   2.447638
# 3        0.799300  -1.857670   2.678128  -0.564379  -0.338822   0.552539
# 4        3.551296  -1.381974   0.881864  -2.512261   0.349712   0.376940
# ...           ...        ...        ...        ...        ...        ...
# 260596   2.148874  -2.001442   2.245711  -1.050846  -2.390093   2.242368
# 260597   3.366335  -0.736915   2.416538   0.168565  -0.939973   1.158304
# 260598   2.024516  -0.775802  -0.138778  -0.885149  -1.246012   0.184863
# 260599   1.692824  -2.603646   1.491476   0.699806  -0.472868  -0.188209
# 260600   1.575717  -2.560175   2.843220  -1.137685   0.192680  -0.146471
#
#         geo_feat7  geo_feat8  geo_feat9  geo_feat10  geo_feat11  geo_feat12  \
# 0        1.614740   0.310817   1.294207    2.312045    1.099191   -2.694324
# 1        1.319128   1.210872   0.418101    0.085968    3.220839   -2.756840
# 2        1.132275  -0.123751   1.817610    1.783720    0.844055   -0.183501
# 3        1.172541  -2.127022  -0.426082    0.068310    1.287670   -0.564273
# 4        1.559291  -0.273731   2.073217    2.099913    2.866739   -1.711959
# ...           ...        ...        ...         ...         ...         ...
# 260596   3.085013   0.736553   2.588622    2.770101    0.798208   -0.344219
# 260597   1.931297   2.721289   3.253176    0.848019    1.506234   -0.499194
# 260598   0.822100  -2.962217   0.678390    2.210722    2.411864   -3.053804
# 260599   1.991306   0.114091  -0.922991    1.797249    2.552944   -1.262327
# 260600   1.479518   1.888092   2.341072    0.860218    1.564397   -2.441492
#
#         geo_feat13  geo_feat14  geo_feat15  geo_feat16
# 0        -3.038431   -0.395711   -2.098679    2.379443
# 1        -0.014923   -1.524271    1.819106   -0.398256
# 2        -2.643142   -3.025988   -2.238920    1.748637
# 3         0.733162   -1.630967   -0.493488   -0.772391
# 4        -1.696779   -1.269688    0.910058   -1.436769
# ...            ...         ...         ...         ...
# 260596   -2.675036   -1.896107   -2.149732    1.634088
# 260597   -2.390478    0.277845    0.590935    0.323059
# 260598   -2.476892   -3.256753    0.190099    2.023416
# 260599   -0.455509   -1.317010    0.762622    1.236359
# 260600   -0.978172   -1.213366    0.618935   -1.013286
#
# [260601 rows x 16 columns]

# %%
train_data = train_x
train_data = train_data.reset_index(drop=True)
train_data = pd.concat([train_data, a],axis=1)
train_data
# Out:
#         geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                    6             487           12198                    2
# 1                    8             900            2812                    2
# 2                   21             363            8973                    2
# 3                   22             418           10694                    2
# 4                   11             131            1488                    3
# ...                ...             ...             ...                  ...
# 260596              25            1335            1621                    1
# 260597              17             715            2060                    2
# 260598              17              51            8163                    3
# 260599              26              39            1851                    2
# 260600              21               9            9101                    3
#
#         age  area_percentage  height_percentage land_surface_condition  \
# 0        30                6                  5                      t
# 1        10                8                  7                      o
# 2        10                5                  5                      t
# 3        10                6                  5                      t
# 4        30                8                  9                      t
# ...     ...              ...                ...                    ...
# 260596   55                6                  3                      n
# 260597    0                6                  5                      t
# 260598   55                6                  7                      t
# 260599   10               14                  6                      t
# 260600   10                7                  6                      n
#
#        foundation_type roof_type  ... geo_feat7 geo_feat8 geo_feat9  \
# 0                    r         n  ...  1.614740  0.310817  1.294207
# 1                    r         n  ...  1.319128  1.210872  0.418101
# 2                    r         n  ...  1.132275 -0.123751  1.817610
# 3                    r         n  ...  1.172541 -2.127022 -0.426082
# 4                    r         n  ...  1.559291 -0.273731  2.073217
# ...                ...       ...  ...       ...       ...       ...
# 260596               r         n  ...  3.085013  0.736553  2.588622
# 260597               r         n  ...  1.931297  2.721289  3.253176
# 260598               r         q  ...  0.822100 -2.962217  0.678390
# 260599               r         x  ...  1.991306  0.114091 -0.922991
# 260600               r         n  ...  1.479518  1.888092  2.341072
#
#        geo_feat10  geo_feat11  geo_feat12  geo_feat13  geo_feat14  geo_feat15  \
# 0        2.312045    1.099191   -2.694324   -3.038431   -0.395711   -2.098679
# 1        0.085968    3.220839   -2.756840   -0.014923   -1.524271    1.819106
# 2        1.783720    0.844055   -0.183501   -2.643142   -3.025988   -2.238920
# 3        0.068310    1.287670   -0.564273    0.733162   -1.630967   -0.493488
# 4        2.099913    2.866739   -1.711959   -1.696779   -1.269688    0.910058
# ...           ...         ...         ...         ...         ...         ...
# 260596   2.770101    0.798208   -0.344219   -2.675036   -1.896107   -2.149732
# 260597   0.848019    1.506234   -0.499194   -2.390478    0.277845    0.590935
# 260598   2.210722    2.411864   -3.053804   -2.476892   -3.256753    0.190099
# 260599   1.797249    2.552944   -1.262327   -0.455509   -1.317010    0.762622
# 260600   0.860218    1.564397   -2.441492   -0.978172   -1.213366    0.618935
#
#         geo_feat16
# 0         2.379443
# 1        -0.398256
# 2         1.748637
# 3        -0.772391
# 4        -1.436769
# ...            ...
# 260596    1.634088
# 260597    0.323059
# 260598    2.023416
# 260599    1.236359
# 260600   -1.013286
#
# [260601 rows x 54 columns]

# %%
train_datai = train_data
train_yi = train_y

# %% [markdown]
# Add new features to test dataset

# %%
geo3_test = test_x["geo_level_3_id"].to_numpy()
geo3_test = torch.tensor(geo3_test, dtype = torch.long)
test_feature = embedModel.get_feature(geo3_test).detach().numpy()

# %%
b = pd.DataFrame(test_feature)
b.columns = ['geo_feat1',
       'geo_feat2', 'geo_feat3', 'geo_feat4', 'geo_feat5', 'geo_feat6',
       'geo_feat7', 'geo_feat8', 'geo_feat9', 'geo_feat10', 'geo_feat11',
       'geo_feat12', 'geo_feat13', 'geo_feat14', 'geo_feat15', 'geo_feat16']
b
# Out:
#        geo_feat1  geo_feat2  geo_feat3  geo_feat4  geo_feat5  geo_feat6  \
# 0       0.154209  -1.855160   1.253630  -0.789279  -1.896688   2.249731
# 1       0.121295  -0.415216   1.014652  -2.486992  -2.975242   0.373346
# 2       2.987561  -0.780578   2.619226  -2.322473  -1.810810   1.877750
# 3       0.456954  -2.972200   1.303150  -0.638250  -1.560437  -0.000236
# 4      -1.038869  -0.778381   0.718419  -2.200065  -1.932974   3.544711
# ...          ...        ...        ...        ...        ...        ...
# 86863  -0.863541   0.128134   0.200570  -0.551044  -0.542065   1.886126
# 86864   1.352502  -3.381880   0.936152  -1.600487   0.048578  -0.013355
# 86865   2.767267  -2.820536   1.210562  -3.086769  -3.763468   3.135728
# 86866   2.787802   0.583902   0.547729  -2.081654  -3.033055   1.247005
# 86867   6.056179  -1.677525   2.270682  -0.680992  -0.500616   1.592982
#
#        geo_feat7  geo_feat8  geo_feat9  geo_feat10  geo_feat11  geo_feat12  \
# 0       1.419226   1.257861   1.160597    1.269671    0.353483   -1.042975
# 1       0.895863   1.330957   0.251000    1.640625    2.393336   -1.281636
# 2       1.436114  -2.764751   3.437391    0.452544    1.102489   -0.453919
# 3       1.775547   1.017376  -0.760987    1.239240    2.199309   -3.075414
# 4       2.211908   0.376664   1.395510    0.647183    2.215909   -0.905522
# ...          ...        ...        ...         ...         ...         ...
# 86863   1.508831  -0.851051   0.060478    0.946763    5.134702   -0.521289
# 86864   3.104919  -0.716980   0.639247    0.094971    0.621013   -1.540782
# 86865   1.954569  -0.181075   2.969114    1.719081    2.619495   -1.152444
# 86866   1.409003   1.109057   1.141922    1.679662    3.395210    0.321554
# 86867   5.553217  -0.962872   4.299562   -1.497341   10.430780   -5.100366
#
#        geo_feat13  geo_feat14  geo_feat15  geo_feat16
# 0        0.555544   -1.673433   -1.057855    1.113611
# 1       -0.325237   -1.758530    0.154713   -0.751193
# 2       -3.045758   -1.204425   -0.880961    1.352055
# 3        0.700020   -2.607163   -0.114532    0.055895
# 4       -0.988486   -2.308328   -0.729297   -0.070338
# ...           ...         ...         ...         ...
# 86863    0.122116   -1.009386    0.520732   -0.149688
# 86864   -0.095112    1.185019    2.525274    0.647403
# 86865   -2.102620   -2.333096   -3.045663    2.381864
# 86866   -0.880071   -0.629335    0.099519    1.869352
# 86867    2.996943   -6.416463    1.320831    3.873994
#
# [86868 rows x 16 columns]

# %%
test_data = test_x
test_data = test_data.reset_index(drop=True)
test_data = pd.concat([test_data, b],axis=1)
test_data
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                  17             596           11307                    3
# 1                   6             141           11987                    2
# 2                  22              19           10044                    2
# 3                  26              39             633                    1
# 4                  17             289            7970                    3
# ...               ...             ...             ...                  ...
# 86863               4             605            3623                    3
# 86864              10            1407           11907                    3
# 86865              22            1136            7712                    1
# 86866               6            1041             912                    2
# 86867              26              36            6436                    2
#
#        age  area_percentage  height_percentage land_surface_condition  \
# 0       20                7                  6                      t
# 1       25               13                  5                      t
# 2        5                4                  5                      t
# 3        0               19                  3                      t
# 4       15                8                  7                      t
# ...    ...              ...                ...                    ...
# 86863   70               20                  6                      t
# 86864   25                6                  7                      n
# 86865   50                3                  3                      t
# 86866    5                9                  5                      t
# 86867   10               11                  4                      t
#
#       foundation_type roof_type  ... geo_feat7 geo_feat8 geo_feat9 geo_feat10  \
# 0                   r         n  ...  1.419226  1.257861  1.160597   1.269671
# 1                   r         n  ...  0.895863  1.330957  0.251000   1.640625
# 2                   r         n  ...  1.436114 -2.764751  3.437391   0.452544
# 3                   r         x  ...  1.775547  1.017376 -0.760987   1.239240
# 4                   r         q  ...  2.211908  0.376664  1.395510   0.647183
# ...               ...       ...  ...       ...       ...       ...        ...
# 86863               r         q  ...  1.508831 -0.851051  0.060478   0.946763
# 86864               r         n  ...  3.104919 -0.716980  0.639247   0.094971
# 86865               r         n  ...  1.954569 -0.181075  2.969114   1.719081
# 86866               r         n  ...  1.409003  1.109057  1.141922   1.679662
# 86867               r         q  ...  5.553217 -0.962872  4.299562  -1.497341
#
#        geo_feat11  geo_feat12  geo_feat13  geo_feat14  geo_feat15  geo_feat16
# 0        0.353483   -1.042975    0.555544   -1.673433   -1.057855    1.113611
# 1        2.393336   -1.281636   -0.325237   -1.758530    0.154713   -0.751193
# 2        1.102489   -0.453919   -3.045758   -1.204425   -0.880961    1.352055
# 3        2.199309   -3.075414    0.700020   -2.607163   -0.114532    0.055895
# 4        2.215909   -0.905522   -0.988486   -2.308328   -0.729297   -0.070338
# ...           ...         ...         ...         ...         ...         ...
# 86863    5.134702   -0.521289    0.122116   -1.009386    0.520732   -0.149688
# 86864    0.621013   -1.540782   -0.095112    1.185019    2.525274    0.647403
# 86865    2.619495   -1.152444   -2.102620   -2.333096   -3.045663    2.381864
# 86866    3.395210    0.321554   -0.880071   -0.629335    0.099519    1.869352
# 86867   10.430780   -5.100366    2.996943   -6.416463    1.320831    3.873994
#
# [86868 rows x 54 columns]

# %%
test_datai = test_data

# %% [markdown]
# Change categorical variable to numeric

# %%
cleanup_letters = {"land_surface_condition": {"n": 1, "o": 2, "t":3},
                "foundation_type": {"h": 1, "i": 2, "r": 3, "u": 4, "w": 5},               
                "roof_type": {"n": 1, "q": 2, "x": 3},
                "ground_floor_type": {"f": 1, "m": 2, "v": 3, "x": 4, "z": 5},
                "other_floor_type": {"j": 1, "q": 2, "s": 3, "x": 4},
                "position": {"j": 1, "o": 2, "s": 3, "t": 4},
                "plan_configuration": {"a": 1, "c": 2, "d": 3, "f": 4, "m": 5, "n": 6, "o": 7, "q": 8, "s": 9, "u":10},
                "legal_ownership_status": {"a": 1, "r": 2, "v": 3, "w": 4}             
               }
train_datai.replace(cleanup_letters, inplace=True)
test_datai.replace(cleanup_letters, inplace=True)

# %%
def threshold_arr(array):
    # Get major confidence-scored predicted value.
    new_arr = []
    for ix, val in enumerate(array):
        loc = np.array(val).argmax(axis=0)
        k = list(np.zeros((len(val))))
        k[loc]=1
        new_arr.append(k)
        
    return np.array(new_arr)

# %%
SEED = 1881

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import f1_score 
from sklearn.model_selection import KFold

# %% [markdown]
# # **Random Forest**

# %% [markdown]
# Training

# %%
from joblib import dump, load

# Assuming your features are in x and target variable in y
y = np.array(train_y["damage_grade"]-1)
x = np.array(train_datai)

# Create the stratified K-fold object
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize the random forest classifier
rf = RandomForestClassifier()

# Loop through the splits and train and evaluate the model
# for train_index, test_index in skf.split(x, y):
#     x_train, x_test = x[train_index], x[test_index]
#     y_train, y_test = y[train_index], y[test_index]
for ix, (train_index, test_index) in enumerate(skf.split(x,y)):
    x_train, x_test, y_train, y_test= x[train_index], x[test_index], y[train_index], y[test_index]
   
    # Train the random forest classifier
    rf.fit(x_train, y_train)

    # Make predictions
    y_pred = rf.predict(x_test)
    #y_pred = np.array(pd.get_dummies(y_pred))
    
    print("F1-MICRO SCORE: ", f1_score(np.array(pd.get_dummies(y_test)), np.array(pd.get_dummies(y_pred)), average='micro'))
    dump(rf, f'models/rfc_model{ix}.joblib')
# Out:
# F1-MICRO SCORE:  0.7251203929318317
# F1-MICRO SCORE:  0.7277628549501152
# F1-MICRO SCORE:  0.7263814274750575
# F1-MICRO SCORE:  0.7268994627782043
# F1-MICRO SCORE:  0.725748273215656

# %% [markdown]
# Submission

# %%
test_datai
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                  17             596           11307                    3
# 1                   6             141           11987                    2
# 2                  22              19           10044                    2
# 3                  26              39             633                    1
# 4                  17             289            7970                    3
# ...               ...             ...             ...                  ...
# 86863               4             605            3623                    3
# 86864              10            1407           11907                    3
# 86865              22            1136            7712                    1
# 86866               6            1041             912                    2
# 86867              26              36            6436                    2
#
#        age  area_percentage  height_percentage  land_surface_condition  \
# 0       20                7                  6                       3
# 1       25               13                  5                       3
# 2        5                4                  5                       3
# 3        0               19                  3                       3
# 4       15                8                  7                       3
# ...    ...              ...                ...                     ...
# 86863   70               20                  6                       3
# 86864   25                6                  7                       1
# 86865   50                3                  3                       3
# 86866    5                9                  5                       3
# 86867   10               11                  4                       3
#
#        foundation_type  roof_type  ...  geo_feat7  geo_feat8  geo_feat9  \
# 0                    3          1  ...   1.419226   1.257861   1.160597
# 1                    3          1  ...   0.895863   1.330957   0.251000
# 2                    3          1  ...   1.436114  -2.764751   3.437391
# 3                    3          3  ...   1.775547   1.017376  -0.760987
# 4                    3          2  ...   2.211908   0.376664   1.395510
# ...                ...        ...  ...        ...        ...        ...
# 86863                3          2  ...   1.508831  -0.851051   0.060478
# 86864                3          1  ...   3.104919  -0.716980   0.639247
# 86865                3          1  ...   1.954569  -0.181075   2.969114
# 86866                3          1  ...   1.409003   1.109057   1.141922
# 86867                3          2  ...   5.553217  -0.962872   4.299562
#
#        geo_feat10  geo_feat11  geo_feat12  geo_feat13  geo_feat14  geo_feat15  \
# 0        1.269671    0.353483   -1.042975    0.555544   -1.673433   -1.057855
# 1        1.640625    2.393336   -1.281636   -0.325237   -1.758530    0.154713
# 2        0.452544    1.102489   -0.453919   -3.045758   -1.204425   -0.880961
# 3        1.239240    2.199309   -3.075414    0.700020   -2.607163   -0.114532
# 4        0.647183    2.215909   -0.905522   -0.988486   -2.308328   -0.729297
# ...           ...         ...         ...         ...         ...         ...
# 86863    0.946763    5.134702   -0.521289    0.122116   -1.009386    0.520732
# 86864    0.094971    0.621013   -1.540782   -0.095112    1.185019    2.525274
# 86865    1.719081    2.619495   -1.152444   -2.102620   -2.333096   -3.045663
# 86866    1.679662    3.395210    0.321554   -0.880071   -0.629335    0.099519
# 86867   -1.497341   10.430780   -5.100366    2.996943   -6.416463    1.320831
#
#        geo_feat16
# 0        1.113611
# 1       -0.751193
# 2        1.352055
# 3        0.055895
# 4       -0.070338
# ...           ...
# 86863   -0.149688
# 86864    0.647403
# 86865    2.381864
# 86866    1.869352
# 86867    3.873994
#
# [86868 rows x 54 columns]

# %%
# Make predictions
df = test_datai
x = np.array(df)
y_pred = rf.predict(x)
y_pred+=1

# %%
sub_csv = pd.read_csv("submission_format.csv")
sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("submission.csv", index=False)

# %% [markdown]
# # **XGBoost**

# %%
def ensemble(models, x):
    # Ensemble K-Fold CV models with adding all confidence score by class.
    y_preds = []
    
    for model in models:
        y_pred = model.predict(x)
        y_preds.append(y_pred)
        
    init_y_pred = y_preds[0]
    for ypred in y_preds[1:]:
        init_y_pred += ypred
        
    y_pred = threshold_arr(init_y_pred)
    
    return y_pred

# %% [markdown]
# Training

# %%
y = np.array(train_y["damage_grade"]-1)
x = np.array(train_datai)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
for ix, (train_index, test_index) in enumerate(skf.split(x,y)):
    x_train, x_valid, y_train, y_valid= x[train_index], x[test_index], y[train_index], y[test_index]
    
    model = XGBClassifier(max_depth = 10, 
                          learning_rate = 0.05,
                          n_estimators = 2000,
                          min_child_weight = 2,
                          objective = 'multiclass',
                          use_label_encoder = False)

    eval_set = [(x_valid, y_valid)]
    model.fit(x_train, y_train, eval_set = eval_set, verbose = 1, early_stopping_rounds = 150)

    y_pred = model.predict(x_valid)
    y_pred = np.array(pd.get_dummies(y_pred))
    
    print("F1-MICRO SCORE: ", f1_score(np.array(pd.get_dummies(y_valid)), y_pred, average='micro'))
    model.save_model(f'models/XGBoost{ix}.txt')
# Out:
# C:\an3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\an3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mlogloss:1.07076
# [1]	validation_0-mlogloss:1.04510
# [2]	validation_0-mlogloss:1.02124
# [3]	validation_0-mlogloss:0.99915
# [4]	validation_0-mlogloss:0.97849
# [5]	validation_0-mlogloss:0.95939
# [6]	validation_0-mlogloss:0.94132
# [7]	validation_0-mlogloss:0.92439
# [8]	validation_0-mlogloss:0.90890
# [9]	validation_0-mlogloss:0.89428
# [10]	validation_0-mlogloss:0.88088
# [11]	validation_0-mlogloss:0.86835
# [12]	validation_0-mlogloss:0.85661
# [13]	validation_0-mlogloss:0.84557
# [14]	validation_0-mlogloss:0.83520
# [15]	validation_0-mlogloss:0.82545
# [16]	validation_0-mlogloss:0.81624
# [17]	validation_0-mlogloss:0.80753
# [18]	validation_0-mlogloss:0.79939
# [19]	validation_0-mlogloss:0.79169
# [20]	validation_0-mlogloss:0.78444
# [21]	validation_0-mlogloss:0.77711
# [22]	validation_0-mlogloss:0.77035
# [23]	validation_0-mlogloss:0.76391
# [24]	validation_0-mlogloss:0.75787
# [25]	validation_0-mlogloss:0.75209
# [26]	validation_0-mlogloss:0.74657
# [27]	validation_0-mlogloss:0.74107
# [28]	validation_0-mlogloss:0.73625
# [29]	validation_0-mlogloss:0.73170
# [30]	validation_0-mlogloss:0.72737
# [31]	validation_0-mlogloss:0.72327
# [32]	validation_0-mlogloss:0.71926
# [33]	validation_0-mlogloss:0.71555
# [34]	validation_0-mlogloss:0.71203
# [35]	validation_0-mlogloss:0.70852
# [36]	validation_0-mlogloss:0.70526
# [37]	validation_0-mlogloss:0.70215
# [38]	validation_0-mlogloss:0.69911
# [39]	validation_0-mlogloss:0.69624
# [40]	validation_0-mlogloss:0.69329
# [41]	validation_0-mlogloss:0.69062
# [42]	validation_0-mlogloss:0.68809
# [43]	validation_0-mlogloss:0.68570
# [44]	validation_0-mlogloss:0.68329
# [45]	validation_0-mlogloss:0.68102
# [46]	validation_0-mlogloss:0.67891
# [47]	validation_0-mlogloss:0.67682
# [48]	validation_0-mlogloss:0.67483
# [49]	validation_0-mlogloss:0.67282
# [50]	validation_0-mlogloss:0.67092
# [51]	validation_0-mlogloss:0.66912
# [52]	validation_0-mlogloss:0.66737
# [53]	validation_0-mlogloss:0.66568
# [54]	validation_0-mlogloss:0.66406
# [55]	validation_0-mlogloss:0.66245
# [56]	validation_0-mlogloss:0.66086
# [57]	validation_0-mlogloss:0.65935
# [58]	validation_0-mlogloss:0.65789
# [59]	validation_0-mlogloss:0.65654
# [60]	validation_0-mlogloss:0.65518
# [61]	validation_0-mlogloss:0.65394
# [62]	validation_0-mlogloss:0.65278
# [63]	validation_0-mlogloss:0.65146
# [64]	validation_0-mlogloss:0.65024
# [65]	validation_0-mlogloss:0.64906
# [66]	validation_0-mlogloss:0.64807
# [67]	validation_0-mlogloss:0.64701
# [68]	validation_0-mlogloss:0.64580
# [69]	validation_0-mlogloss:0.64483
# [70]	validation_0-mlogloss:0.64393
# [71]	validation_0-mlogloss:0.64287
# [72]	validation_0-mlogloss:0.64201
# [73]	validation_0-mlogloss:0.64111
# [74]	validation_0-mlogloss:0.64014
# [75]	validation_0-mlogloss:0.63931
# [76]	validation_0-mlogloss:0.63846
# [77]	validation_0-mlogloss:0.63774
# [78]	validation_0-mlogloss:0.63700
# [79]	validation_0-mlogloss:0.63610
# [80]	validation_0-mlogloss:0.63537
# [81]	validation_0-mlogloss:0.63452
# [82]	validation_0-mlogloss:0.63385
# [83]	validation_0-mlogloss:0.63307
# [84]	validation_0-mlogloss:0.63245
# [85]	validation_0-mlogloss:0.63171
# [86]	validation_0-mlogloss:0.63078
# [87]	validation_0-mlogloss:0.63013
# [88]	validation_0-mlogloss:0.62948
# [89]	validation_0-mlogloss:0.62873
# [90]	validation_0-mlogloss:0.62805
# [91]	validation_0-mlogloss:0.62742
# [92]	validation_0-mlogloss:0.62685
# [93]	validation_0-mlogloss:0.62610
# [94]	validation_0-mlogloss:0.62545
# [95]	validation_0-mlogloss:0.62486
# [96]	validation_0-mlogloss:0.62423
# [97]	validation_0-mlogloss:0.62367
# [98]	validation_0-mlogloss:0.62311
# [99]	validation_0-mlogloss:0.62257
# [100]	validation_0-mlogloss:0.62215
# [101]	validation_0-mlogloss:0.62135
# [102]	validation_0-mlogloss:0.62084
# [103]	validation_0-mlogloss:0.62018
# [104]	validation_0-mlogloss:0.61957
# [105]	validation_0-mlogloss:0.61915
# [106]	validation_0-mlogloss:0.61860
# [107]	validation_0-mlogloss:0.61810
# [108]	validation_0-mlogloss:0.61763
# [109]	validation_0-mlogloss:0.61712
# [110]	validation_0-mlogloss:0.61660
# [111]	validation_0-mlogloss:0.61613
# [112]	validation_0-mlogloss:0.61564
# [113]	validation_0-mlogloss:0.61518
# [114]	validation_0-mlogloss:0.61474
# [115]	validation_0-mlogloss:0.61431
# [116]	validation_0-mlogloss:0.61395
# [117]	validation_0-mlogloss:0.61363
# [118]	validation_0-mlogloss:0.61320
# [119]	validation_0-mlogloss:0.61279
# [120]	validation_0-mlogloss:0.61231
# [121]	validation_0-mlogloss:0.61198
# [122]	validation_0-mlogloss:0.61161
# [123]	validation_0-mlogloss:0.61118
# [124]	validation_0-mlogloss:0.61088
# [125]	validation_0-mlogloss:0.61051
# [126]	validation_0-mlogloss:0.61018
# [127]	validation_0-mlogloss:0.60984
# [128]	validation_0-mlogloss:0.60945
# [129]	validation_0-mlogloss:0.60917
# [130]	validation_0-mlogloss:0.60867
# [131]	validation_0-mlogloss:0.60828
# [132]	validation_0-mlogloss:0.60780
# [133]	validation_0-mlogloss:0.60754
# [134]	validation_0-mlogloss:0.60714
# [135]	validation_0-mlogloss:0.60686
# [136]	validation_0-mlogloss:0.60643
# [137]	validation_0-mlogloss:0.60614
# [138]	validation_0-mlogloss:0.60587
# [139]	validation_0-mlogloss:0.60554
# [140]	validation_0-mlogloss:0.60529
# [141]	validation_0-mlogloss:0.60499
# [142]	validation_0-mlogloss:0.60470
# [143]	validation_0-mlogloss:0.60425
# [144]	validation_0-mlogloss:0.60392
# [145]	validation_0-mlogloss:0.60363
# [146]	validation_0-mlogloss:0.60325
# [147]	validation_0-mlogloss:0.60301
# [148]	validation_0-mlogloss:0.60281
# [149]	validation_0-mlogloss:0.60259
# [150]	validation_0-mlogloss:0.60230
# [151]	validation_0-mlogloss:0.60194
# [152]	validation_0-mlogloss:0.60163
# [153]	validation_0-mlogloss:0.60135
# [154]	validation_0-mlogloss:0.60092
# [155]	validation_0-mlogloss:0.60065
# [156]	validation_0-mlogloss:0.60042
# [157]	validation_0-mlogloss:0.60002
# [158]	validation_0-mlogloss:0.59976
# [159]	validation_0-mlogloss:0.59954
# [160]	validation_0-mlogloss:0.59921
# [161]	validation_0-mlogloss:0.59898
# [162]	validation_0-mlogloss:0.59858
# [163]	validation_0-mlogloss:0.59834
# [164]	validation_0-mlogloss:0.59809
# [165]	validation_0-mlogloss:0.59777
# [166]	validation_0-mlogloss:0.59749
# [167]	validation_0-mlogloss:0.59730
# [168]	validation_0-mlogloss:0.59712
# [169]	validation_0-mlogloss:0.59684
# [170]	validation_0-mlogloss:0.59656
# [171]	validation_0-mlogloss:0.59624
# [172]	validation_0-mlogloss:0.59594
# [173]	validation_0-mlogloss:0.59566
# [174]	validation_0-mlogloss:0.59549
# [175]	validation_0-mlogloss:0.59528
# [176]	validation_0-mlogloss:0.59508
# [177]	validation_0-mlogloss:0.59487
# [178]	validation_0-mlogloss:0.59469
# [179]	validation_0-mlogloss:0.59460
# [180]	validation_0-mlogloss:0.59434
# [181]	validation_0-mlogloss:0.59414
# [182]	validation_0-mlogloss:0.59387
# [183]	validation_0-mlogloss:0.59365
# [184]	validation_0-mlogloss:0.59343
# [185]	validation_0-mlogloss:0.59333
# [186]	validation_0-mlogloss:0.59312
# [187]	validation_0-mlogloss:0.59297
# [188]	validation_0-mlogloss:0.59283
# [189]	validation_0-mlogloss:0.59265
# [190]	validation_0-mlogloss:0.59249
# [191]	validation_0-mlogloss:0.59231
# [192]	validation_0-mlogloss:0.59214
# [193]	validation_0-mlogloss:0.59196
# [194]	validation_0-mlogloss:0.59184
# [195]	validation_0-mlogloss:0.59165
# [196]	validation_0-mlogloss:0.59143
# [197]	validation_0-mlogloss:0.59125
# [198]	validation_0-mlogloss:0.59117
# [199]	validation_0-mlogloss:0.59097
# [200]	validation_0-mlogloss:0.59081
# [201]	validation_0-mlogloss:0.59070
# [202]	validation_0-mlogloss:0.59053
# [203]	validation_0-mlogloss:0.59033
# [204]	validation_0-mlogloss:0.59025
# [205]	validation_0-mlogloss:0.59005
# [206]	validation_0-mlogloss:0.58996
# [207]	validation_0-mlogloss:0.58983
# [208]	validation_0-mlogloss:0.58965
# [209]	validation_0-mlogloss:0.58959
# [210]	validation_0-mlogloss:0.58941
# [211]	validation_0-mlogloss:0.58928
# [212]	validation_0-mlogloss:0.58912
# [213]	validation_0-mlogloss:0.58901
# [214]	validation_0-mlogloss:0.58878
# [215]	validation_0-mlogloss:0.58867
# [216]	validation_0-mlogloss:0.58857
# [217]	validation_0-mlogloss:0.58846
# [218]	validation_0-mlogloss:0.58831
# [219]	validation_0-mlogloss:0.58813
# [220]	validation_0-mlogloss:0.58798
# [221]	validation_0-mlogloss:0.58779
# [222]	validation_0-mlogloss:0.58760
# [223]	validation_0-mlogloss:0.58741
# [224]	validation_0-mlogloss:0.58724
# [225]	validation_0-mlogloss:0.58714
# [226]	validation_0-mlogloss:0.58704
# [227]	validation_0-mlogloss:0.58685
# [228]	validation_0-mlogloss:0.58673
# [229]	validation_0-mlogloss:0.58649
# [230]	validation_0-mlogloss:0.58634
# [231]	validation_0-mlogloss:0.58623
# [232]	validation_0-mlogloss:0.58612
# [233]	validation_0-mlogloss:0.58608
# [234]	validation_0-mlogloss:0.58603
# [235]	validation_0-mlogloss:0.58593
# [236]	validation_0-mlogloss:0.58585
# [237]	validation_0-mlogloss:0.58560
# [238]	validation_0-mlogloss:0.58552
# [239]	validation_0-mlogloss:0.58533
# [240]	validation_0-mlogloss:0.58515
# [241]	validation_0-mlogloss:0.58507
# [242]	validation_0-mlogloss:0.58497
# [243]	validation_0-mlogloss:0.58486
# [244]	validation_0-mlogloss:0.58471
# [245]	validation_0-mlogloss:0.58453
# [246]	validation_0-mlogloss:0.58446
# [247]	validation_0-mlogloss:0.58434
# [248]	validation_0-mlogloss:0.58418
# [249]	validation_0-mlogloss:0.58406
# [250]	validation_0-mlogloss:0.58397
# [251]	validation_0-mlogloss:0.58385
# [252]	validation_0-mlogloss:0.58363
# [253]	validation_0-mlogloss:0.58348
# [254]	validation_0-mlogloss:0.58332
# [255]	validation_0-mlogloss:0.58324
# [256]	validation_0-mlogloss:0.58306
# [257]	validation_0-mlogloss:0.58286
# [258]	validation_0-mlogloss:0.58281
# [259]	validation_0-mlogloss:0.58259
# [260]	validation_0-mlogloss:0.58246
# [261]	validation_0-mlogloss:0.58241
# [262]	validation_0-mlogloss:0.58237
# [263]	validation_0-mlogloss:0.58231
# [264]	validation_0-mlogloss:0.58221
# [265]	validation_0-mlogloss:0.58199
# [266]	validation_0-mlogloss:0.58173
# [267]	validation_0-mlogloss:0.58160
# [268]	validation_0-mlogloss:0.58147
# [269]	validation_0-mlogloss:0.58138
# [270]	validation_0-mlogloss:0.58117
# [271]	validation_0-mlogloss:0.58100
# [272]	validation_0-mlogloss:0.58092
# [273]	validation_0-mlogloss:0.58087
# [274]	validation_0-mlogloss:0.58077
# [275]	validation_0-mlogloss:0.58069
# [276]	validation_0-mlogloss:0.58059
# [277]	validation_0-mlogloss:0.58050
# [278]	validation_0-mlogloss:0.58044
# [279]	validation_0-mlogloss:0.58025
# [280]	validation_0-mlogloss:0.58020
# [281]	validation_0-mlogloss:0.58012
# [282]	validation_0-mlogloss:0.58007
# [283]	validation_0-mlogloss:0.58001
# [284]	validation_0-mlogloss:0.57984
# [285]	validation_0-mlogloss:0.57971
# [286]	validation_0-mlogloss:0.57966
# [287]	validation_0-mlogloss:0.57947
# [288]	validation_0-mlogloss:0.57923
# [289]	validation_0-mlogloss:0.57907
# [290]	validation_0-mlogloss:0.57902
# [291]	validation_0-mlogloss:0.57892
# [292]	validation_0-mlogloss:0.57887
# [293]	validation_0-mlogloss:0.57870
# [294]	validation_0-mlogloss:0.57857
# [295]	validation_0-mlogloss:0.57850
# [296]	validation_0-mlogloss:0.57827
# [297]	validation_0-mlogloss:0.57820
# [298]	validation_0-mlogloss:0.57812
# [299]	validation_0-mlogloss:0.57797
# [300]	validation_0-mlogloss:0.57790
# [301]	validation_0-mlogloss:0.57787
# [302]	validation_0-mlogloss:0.57782
# [303]	validation_0-mlogloss:0.57777
# [304]	validation_0-mlogloss:0.57769
# [305]	validation_0-mlogloss:0.57753
# [306]	validation_0-mlogloss:0.57750
# [307]	validation_0-mlogloss:0.57748
# [308]	validation_0-mlogloss:0.57734
# [309]	validation_0-mlogloss:0.57731
# [310]	validation_0-mlogloss:0.57724
# [311]	validation_0-mlogloss:0.57720
# [312]	validation_0-mlogloss:0.57710
# [313]	validation_0-mlogloss:0.57694
# [314]	validation_0-mlogloss:0.57686
# [315]	validation_0-mlogloss:0.57670
# [316]	validation_0-mlogloss:0.57659
# [317]	validation_0-mlogloss:0.57652
# [318]	validation_0-mlogloss:0.57645
# [319]	validation_0-mlogloss:0.57628
# [320]	validation_0-mlogloss:0.57622
# [321]	validation_0-mlogloss:0.57621
# [322]	validation_0-mlogloss:0.57613
# [323]	validation_0-mlogloss:0.57602
# [324]	validation_0-mlogloss:0.57585
# [325]	validation_0-mlogloss:0.57578
# [326]	validation_0-mlogloss:0.57565
# [327]	validation_0-mlogloss:0.57561
# [328]	validation_0-mlogloss:0.57559
# [329]	validation_0-mlogloss:0.57546
# [330]	validation_0-mlogloss:0.57536
# [331]	validation_0-mlogloss:0.57529
# [332]	validation_0-mlogloss:0.57525
# [333]	validation_0-mlogloss:0.57517
# [334]	validation_0-mlogloss:0.57503
# [335]	validation_0-mlogloss:0.57503
# [336]	validation_0-mlogloss:0.57495
# [337]	validation_0-mlogloss:0.57489
# [338]	validation_0-mlogloss:0.57482
# [339]	validation_0-mlogloss:0.57465
# [340]	validation_0-mlogloss:0.57462
# [341]	validation_0-mlogloss:0.57458
# [342]	validation_0-mlogloss:0.57455
# [343]	validation_0-mlogloss:0.57447
# [344]	validation_0-mlogloss:0.57444
# [345]	validation_0-mlogloss:0.57436
# [346]	validation_0-mlogloss:0.57428
# [347]	validation_0-mlogloss:0.57420
# [348]	validation_0-mlogloss:0.57413
# [349]	validation_0-mlogloss:0.57410
# [350]	validation_0-mlogloss:0.57409
# [351]	validation_0-mlogloss:0.57401
# [352]	validation_0-mlogloss:0.57399
# [353]	validation_0-mlogloss:0.57391
# [354]	validation_0-mlogloss:0.57385
# [355]	validation_0-mlogloss:0.57381
# [356]	validation_0-mlogloss:0.57377
# [357]	validation_0-mlogloss:0.57373
# [358]	validation_0-mlogloss:0.57364
# [359]	validation_0-mlogloss:0.57352
# [360]	validation_0-mlogloss:0.57347
# [361]	validation_0-mlogloss:0.57341
# [362]	validation_0-mlogloss:0.57335
# [363]	validation_0-mlogloss:0.57331
# [364]	validation_0-mlogloss:0.57319
# [365]	validation_0-mlogloss:0.57310
# [366]	validation_0-mlogloss:0.57302
# [367]	validation_0-mlogloss:0.57299
# [368]	validation_0-mlogloss:0.57297
# [369]	validation_0-mlogloss:0.57291
# [370]	validation_0-mlogloss:0.57287
# [371]	validation_0-mlogloss:0.57284
# [372]	validation_0-mlogloss:0.57280
# [373]	validation_0-mlogloss:0.57271
# [374]	validation_0-mlogloss:0.57269
# [375]	validation_0-mlogloss:0.57262
# [376]	validation_0-mlogloss:0.57251
# [377]	validation_0-mlogloss:0.57250
# [378]	validation_0-mlogloss:0.57245
# [379]	validation_0-mlogloss:0.57242
# [380]	validation_0-mlogloss:0.57230
# [381]	validation_0-mlogloss:0.57228
# [382]	validation_0-mlogloss:0.57226
# [383]	validation_0-mlogloss:0.57216
# [384]	validation_0-mlogloss:0.57212
# [385]	validation_0-mlogloss:0.57209
# [386]	validation_0-mlogloss:0.57207
# [387]	validation_0-mlogloss:0.57204
# [388]	validation_0-mlogloss:0.57199
# [389]	validation_0-mlogloss:0.57196
# [390]	validation_0-mlogloss:0.57191
# [391]	validation_0-mlogloss:0.57189
# [392]	validation_0-mlogloss:0.57185
# [393]	validation_0-mlogloss:0.57180
# [394]	validation_0-mlogloss:0.57180
# [395]	validation_0-mlogloss:0.57170
# [396]	validation_0-mlogloss:0.57166
# [397]	validation_0-mlogloss:0.57160
# [398]	validation_0-mlogloss:0.57159
# [399]	validation_0-mlogloss:0.57160
# [400]	validation_0-mlogloss:0.57151
# [401]	validation_0-mlogloss:0.57149
# [402]	validation_0-mlogloss:0.57145
# [403]	validation_0-mlogloss:0.57140
# [404]	validation_0-mlogloss:0.57138
# [405]	validation_0-mlogloss:0.57129
# [406]	validation_0-mlogloss:0.57126
# [407]	validation_0-mlogloss:0.57126
# [408]	validation_0-mlogloss:0.57126
# [409]	validation_0-mlogloss:0.57123
# [410]	validation_0-mlogloss:0.57116
# [411]	validation_0-mlogloss:0.57112
# [412]	validation_0-mlogloss:0.57107
# [413]	validation_0-mlogloss:0.57102
# [414]	validation_0-mlogloss:0.57098
# [415]	validation_0-mlogloss:0.57091
# [416]	validation_0-mlogloss:0.57089
# [417]	validation_0-mlogloss:0.57084
# [418]	validation_0-mlogloss:0.57084
# [419]	validation_0-mlogloss:0.57084
# [420]	validation_0-mlogloss:0.57081
# [421]	validation_0-mlogloss:0.57073
# [422]	validation_0-mlogloss:0.57071
# [423]	validation_0-mlogloss:0.57067
# [424]	validation_0-mlogloss:0.57067
# [425]	validation_0-mlogloss:0.57063
# [426]	validation_0-mlogloss:0.57061
# [427]	validation_0-mlogloss:0.57060
# [428]	validation_0-mlogloss:0.57053
# [429]	validation_0-mlogloss:0.57049
# [430]	validation_0-mlogloss:0.57046
# [431]	validation_0-mlogloss:0.57045
# [432]	validation_0-mlogloss:0.57040
# [433]	validation_0-mlogloss:0.57039
# [434]	validation_0-mlogloss:0.57039
# [435]	validation_0-mlogloss:0.57037
# [436]	validation_0-mlogloss:0.57034
# [437]	validation_0-mlogloss:0.57030
# [438]	validation_0-mlogloss:0.57029
# [439]	validation_0-mlogloss:0.57019
# [440]	validation_0-mlogloss:0.57013
# [441]	validation_0-mlogloss:0.57009
# [442]	validation_0-mlogloss:0.57008
# [443]	validation_0-mlogloss:0.57008
# [444]	validation_0-mlogloss:0.57000
# [445]	validation_0-mlogloss:0.56994
# [446]	validation_0-mlogloss:0.56992
# [447]	validation_0-mlogloss:0.56993
# [448]	validation_0-mlogloss:0.56988
# [449]	validation_0-mlogloss:0.56988
# [450]	validation_0-mlogloss:0.56982
# [451]	validation_0-mlogloss:0.56978
# [452]	validation_0-mlogloss:0.56977
# [453]	validation_0-mlogloss:0.56969
# [454]	validation_0-mlogloss:0.56966
# [455]	validation_0-mlogloss:0.56963
# [456]	validation_0-mlogloss:0.56954
# [457]	validation_0-mlogloss:0.56951
# [458]	validation_0-mlogloss:0.56948
# [459]	validation_0-mlogloss:0.56946
# [460]	validation_0-mlogloss:0.56940
# [461]	validation_0-mlogloss:0.56938
# [462]	validation_0-mlogloss:0.56936
# [463]	validation_0-mlogloss:0.56931
# [464]	validation_0-mlogloss:0.56928
# [465]	validation_0-mlogloss:0.56925
# [466]	validation_0-mlogloss:0.56923
# [467]	validation_0-mlogloss:0.56922
# [468]	validation_0-mlogloss:0.56919
# [469]	validation_0-mlogloss:0.56921
# [470]	validation_0-mlogloss:0.56919
# [471]	validation_0-mlogloss:0.56915
# [472]	validation_0-mlogloss:0.56915
# [473]	validation_0-mlogloss:0.56913
# [474]	validation_0-mlogloss:0.56909
# [475]	validation_0-mlogloss:0.56907
# [476]	validation_0-mlogloss:0.56909
# [477]	validation_0-mlogloss:0.56905
# [478]	validation_0-mlogloss:0.56902
# [479]	validation_0-mlogloss:0.56896
# [480]	validation_0-mlogloss:0.56896
# [481]	validation_0-mlogloss:0.56892
# [482]	validation_0-mlogloss:0.56888
# [483]	validation_0-mlogloss:0.56886
# [484]	validation_0-mlogloss:0.56882
# [485]	validation_0-mlogloss:0.56883
# [486]	validation_0-mlogloss:0.56878
# [487]	validation_0-mlogloss:0.56877
# [488]	validation_0-mlogloss:0.56875
# [489]	validation_0-mlogloss:0.56874
# [490]	validation_0-mlogloss:0.56875
# [491]	validation_0-mlogloss:0.56870
# [492]	validation_0-mlogloss:0.56870
# [493]	validation_0-mlogloss:0.56868
# [494]	validation_0-mlogloss:0.56868
# [495]	validation_0-mlogloss:0.56867
# [496]	validation_0-mlogloss:0.56866
# [497]	validation_0-mlogloss:0.56864
# [498]	validation_0-mlogloss:0.56865
# [499]	validation_0-mlogloss:0.56863
# [500]	validation_0-mlogloss:0.56863
# [501]	validation_0-mlogloss:0.56862
# [502]	validation_0-mlogloss:0.56863
# [503]	validation_0-mlogloss:0.56862
# [504]	validation_0-mlogloss:0.56858
# [505]	validation_0-mlogloss:0.56857
# [506]	validation_0-mlogloss:0.56852
# [507]	validation_0-mlogloss:0.56849
# [508]	validation_0-mlogloss:0.56848
# [509]	validation_0-mlogloss:0.56844
# [510]	validation_0-mlogloss:0.56843
# [511]	validation_0-mlogloss:0.56840
# [512]	validation_0-mlogloss:0.56841
# [513]	validation_0-mlogloss:0.56841
# [514]	validation_0-mlogloss:0.56839
# [515]	validation_0-mlogloss:0.56836
# [516]	validation_0-mlogloss:0.56832
# [517]	validation_0-mlogloss:0.56827
# [518]	validation_0-mlogloss:0.56828
# [519]	validation_0-mlogloss:0.56829
# [520]	validation_0-mlogloss:0.56827
# [521]	validation_0-mlogloss:0.56828
# [522]	validation_0-mlogloss:0.56826
# [523]	validation_0-mlogloss:0.56825
# [524]	validation_0-mlogloss:0.56824
# [525]	validation_0-mlogloss:0.56821
# [526]	validation_0-mlogloss:0.56821
# [527]	validation_0-mlogloss:0.56818
# [528]	validation_0-mlogloss:0.56818
# [529]	validation_0-mlogloss:0.56818
# [530]	validation_0-mlogloss:0.56815
# [531]	validation_0-mlogloss:0.56814
# [532]	validation_0-mlogloss:0.56809
# [533]	validation_0-mlogloss:0.56811
# [534]	validation_0-mlogloss:0.56808
# [535]	validation_0-mlogloss:0.56806
# [536]	validation_0-mlogloss:0.56804
# [537]	validation_0-mlogloss:0.56804
# [538]	validation_0-mlogloss:0.56801
# [539]	validation_0-mlogloss:0.56800
# [540]	validation_0-mlogloss:0.56799
# [541]	validation_0-mlogloss:0.56798
# [542]	validation_0-mlogloss:0.56796
# [543]	validation_0-mlogloss:0.56793
# [544]	validation_0-mlogloss:0.56792
# [545]	validation_0-mlogloss:0.56789
# [546]	validation_0-mlogloss:0.56788
# [547]	validation_0-mlogloss:0.56786
# [548]	validation_0-mlogloss:0.56785
# [549]	validation_0-mlogloss:0.56784
# [550]	validation_0-mlogloss:0.56786
# [551]	validation_0-mlogloss:0.56784
# [552]	validation_0-mlogloss:0.56785
# [553]	validation_0-mlogloss:0.56784
# [554]	validation_0-mlogloss:0.56782
# [555]	validation_0-mlogloss:0.56784
# [556]	validation_0-mlogloss:0.56782
# [557]	validation_0-mlogloss:0.56778
# [558]	validation_0-mlogloss:0.56778
# [559]	validation_0-mlogloss:0.56777
# [560]	validation_0-mlogloss:0.56778
# [561]	validation_0-mlogloss:0.56776
# [562]	validation_0-mlogloss:0.56775
# [563]	validation_0-mlogloss:0.56775
# [564]	validation_0-mlogloss:0.56773
# [565]	validation_0-mlogloss:0.56773
# [566]	validation_0-mlogloss:0.56771
# [567]	validation_0-mlogloss:0.56771
# [568]	validation_0-mlogloss:0.56771
# [569]	validation_0-mlogloss:0.56767
# [570]	validation_0-mlogloss:0.56767
# [571]	validation_0-mlogloss:0.56767
# [572]	validation_0-mlogloss:0.56770
# [573]	validation_0-mlogloss:0.56771
# [574]	validation_0-mlogloss:0.56772
# [575]	validation_0-mlogloss:0.56771
# [576]	validation_0-mlogloss:0.56772
# [577]	validation_0-mlogloss:0.56769
# [578]	validation_0-mlogloss:0.56769
# [579]	validation_0-mlogloss:0.56769
# [580]	validation_0-mlogloss:0.56768
# [581]	validation_0-mlogloss:0.56769
# [582]	validation_0-mlogloss:0.56769
# [583]	validation_0-mlogloss:0.56770
# [584]	validation_0-mlogloss:0.56770
# [585]	validation_0-mlogloss:0.56771
# [586]	validation_0-mlogloss:0.56771
# [587]	validation_0-mlogloss:0.56771
# [588]	validation_0-mlogloss:0.56771
# [589]	validation_0-mlogloss:0.56770
# [590]	validation_0-mlogloss:0.56771
# [591]	validation_0-mlogloss:0.56767
# [592]	validation_0-mlogloss:0.56768
# [593]	validation_0-mlogloss:0.56768
# [594]	validation_0-mlogloss:0.56771
# [595]	validation_0-mlogloss:0.56769
# [596]	validation_0-mlogloss:0.56769
# [597]	validation_0-mlogloss:0.56768
# [598]	validation_0-mlogloss:0.56769
# [599]	validation_0-mlogloss:0.56770
# [600]	validation_0-mlogloss:0.56769
# [601]	validation_0-mlogloss:0.56769
# [602]	validation_0-mlogloss:0.56767
# [603]	validation_0-mlogloss:0.56768
# [604]	validation_0-mlogloss:0.56769
# [605]	validation_0-mlogloss:0.56769
# [606]	validation_0-mlogloss:0.56770
# [607]	validation_0-mlogloss:0.56770
# [608]	validation_0-mlogloss:0.56771
# [609]	validation_0-mlogloss:0.56771
# [610]	validation_0-mlogloss:0.56771
# [611]	validation_0-mlogloss:0.56772
# [612]	validation_0-mlogloss:0.56773
# [613]	validation_0-mlogloss:0.56773
# [614]	validation_0-mlogloss:0.56772
# [615]	validation_0-mlogloss:0.56772
# [616]	validation_0-mlogloss:0.56772
# [617]	validation_0-mlogloss:0.56772
# [618]	validation_0-mlogloss:0.56774
# [619]	validation_0-mlogloss:0.56776
# [620]	validation_0-mlogloss:0.56777
# [621]	validation_0-mlogloss:0.56780
# [622]	validation_0-mlogloss:0.56780
# [623]	validation_0-mlogloss:0.56781
# [624]	validation_0-mlogloss:0.56779
# [625]	validation_0-mlogloss:0.56777
# [626]	validation_0-mlogloss:0.56776
# [627]	validation_0-mlogloss:0.56774
# [628]	validation_0-mlogloss:0.56774
# [629]	validation_0-mlogloss:0.56775
# [630]	validation_0-mlogloss:0.56775
# [631]	validation_0-mlogloss:0.56775
# [632]	validation_0-mlogloss:0.56776
# [633]	validation_0-mlogloss:0.56776
# [634]	validation_0-mlogloss:0.56776
# [635]	validation_0-mlogloss:0.56777
# [636]	validation_0-mlogloss:0.56775
# [637]	validation_0-mlogloss:0.56776
# [638]	validation_0-mlogloss:0.56777
# [639]	validation_0-mlogloss:0.56775
# [640]	validation_0-mlogloss:0.56775
# [641]	validation_0-mlogloss:0.56776
# [642]	validation_0-mlogloss:0.56776
# [643]	validation_0-mlogloss:0.56777
# [644]	validation_0-mlogloss:0.56778
# [645]	validation_0-mlogloss:0.56780
# [646]	validation_0-mlogloss:0.56781
# [647]	validation_0-mlogloss:0.56782
# [648]	validation_0-mlogloss:0.56784
# [649]	validation_0-mlogloss:0.56784
# [650]	validation_0-mlogloss:0.56783
# [651]	validation_0-mlogloss:0.56784
# [652]	validation_0-mlogloss:0.56784
# [653]	validation_0-mlogloss:0.56786
# [654]	validation_0-mlogloss:0.56786
# [655]	validation_0-mlogloss:0.56785
# [656]	validation_0-mlogloss:0.56788
# [657]	validation_0-mlogloss:0.56787
# [658]	validation_0-mlogloss:0.56788
# [659]	validation_0-mlogloss:0.56788
# [660]	validation_0-mlogloss:0.56788
# [661]	validation_0-mlogloss:0.56791
# [662]	validation_0-mlogloss:0.56792
# [663]	validation_0-mlogloss:0.56793
# [664]	validation_0-mlogloss:0.56793
# [665]	validation_0-mlogloss:0.56791
# [666]	validation_0-mlogloss:0.56791
# [667]	validation_0-mlogloss:0.56791
# [668]	validation_0-mlogloss:0.56791
# [669]	validation_0-mlogloss:0.56791
# [670]	validation_0-mlogloss:0.56791
# [671]	validation_0-mlogloss:0.56796
# [672]	validation_0-mlogloss:0.56797
# [673]	validation_0-mlogloss:0.56798
# [674]	validation_0-mlogloss:0.56799
# [675]	validation_0-mlogloss:0.56800
# [676]	validation_0-mlogloss:0.56802
# [677]	validation_0-mlogloss:0.56801
# [678]	validation_0-mlogloss:0.56803
# [679]	validation_0-mlogloss:0.56803
# [680]	validation_0-mlogloss:0.56806
# [681]	validation_0-mlogloss:0.56806
# [682]	validation_0-mlogloss:0.56807
# [683]	validation_0-mlogloss:0.56809
# [684]	validation_0-mlogloss:0.56807
# [685]	validation_0-mlogloss:0.56808
# [686]	validation_0-mlogloss:0.56810
# [687]	validation_0-mlogloss:0.56812
# [688]	validation_0-mlogloss:0.56812
# [689]	validation_0-mlogloss:0.56813
# [690]	validation_0-mlogloss:0.56813
# [691]	validation_0-mlogloss:0.56814
# [692]	validation_0-mlogloss:0.56812
# [693]	validation_0-mlogloss:0.56812
# [694]	validation_0-mlogloss:0.56813
# [695]	validation_0-mlogloss:0.56812
# [696]	validation_0-mlogloss:0.56813
# [697]	validation_0-mlogloss:0.56814
# [698]	validation_0-mlogloss:0.56817
# [699]	validation_0-mlogloss:0.56818
# [700]	validation_0-mlogloss:0.56817
# [701]	validation_0-mlogloss:0.56817
# [702]	validation_0-mlogloss:0.56817
# [703]	validation_0-mlogloss:0.56817
# [704]	validation_0-mlogloss:0.56815
# [705]	validation_0-mlogloss:0.56815
# [706]	validation_0-mlogloss:0.56817
# [707]	validation_0-mlogloss:0.56817
# [708]	validation_0-mlogloss:0.56816
# [709]	validation_0-mlogloss:0.56817
# [710]	validation_0-mlogloss:0.56818
# [711]	validation_0-mlogloss:0.56818
# [712]	validation_0-mlogloss:0.56818
# [713]	validation_0-mlogloss:0.56819
# [714]	validation_0-mlogloss:0.56820
# [715]	validation_0-mlogloss:0.56820
# [716]	validation_0-mlogloss:0.56822
# [717]	validation_0-mlogloss:0.56822
# [718]	validation_0-mlogloss:0.56821
# [719]	validation_0-mlogloss:0.56821
# [720]	validation_0-mlogloss:0.56821
# [721]	validation_0-mlogloss:0.56823
# [722]	validation_0-mlogloss:0.56825
# [723]	validation_0-mlogloss:0.56826
# [724]	validation_0-mlogloss:0.56825
# [725]	validation_0-mlogloss:0.56823
# [726]	validation_0-mlogloss:0.56824
# [727]	validation_0-mlogloss:0.56825
# [728]	validation_0-mlogloss:0.56825
# [729]	validation_0-mlogloss:0.56826
# [730]	validation_0-mlogloss:0.56828
# [731]	validation_0-mlogloss:0.56829
# [732]	validation_0-mlogloss:0.56831
# [733]	validation_0-mlogloss:0.56832
# [734]	validation_0-mlogloss:0.56830
# [735]	validation_0-mlogloss:0.56832
# [736]	validation_0-mlogloss:0.56831
# [737]	validation_0-mlogloss:0.56834
# [738]	validation_0-mlogloss:0.56834
# [739]	validation_0-mlogloss:0.56836
# [740]	validation_0-mlogloss:0.56834
# F1-MICRO SCORE:  0.7494675850424971
# C:\an3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\an3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mlogloss:1.07093
# [1]	validation_0-mlogloss:1.04545
# [2]	validation_0-mlogloss:1.02192
# [3]	validation_0-mlogloss:1.00010
# [4]	validation_0-mlogloss:0.97983
# [5]	validation_0-mlogloss:0.96080
# [6]	validation_0-mlogloss:0.94330
# [7]	validation_0-mlogloss:0.92669
# [8]	validation_0-mlogloss:0.91125
# [9]	validation_0-mlogloss:0.89682
# [10]	validation_0-mlogloss:0.88344
# [11]	validation_0-mlogloss:0.87087
# [12]	validation_0-mlogloss:0.85929
# [13]	validation_0-mlogloss:0.84826
# [14]	validation_0-mlogloss:0.83786
# [15]	validation_0-mlogloss:0.82807
# [16]	validation_0-mlogloss:0.81884
# [17]	validation_0-mlogloss:0.81016
# [18]	validation_0-mlogloss:0.80195
# [19]	validation_0-mlogloss:0.79424
# [20]	validation_0-mlogloss:0.78700
# [21]	validation_0-mlogloss:0.77976
# [22]	validation_0-mlogloss:0.77326
# [23]	validation_0-mlogloss:0.76681
# [24]	validation_0-mlogloss:0.76070
# [25]	validation_0-mlogloss:0.75496
# [26]	validation_0-mlogloss:0.74938
# [27]	validation_0-mlogloss:0.74412
# [28]	validation_0-mlogloss:0.73904
# [29]	validation_0-mlogloss:0.73441
# [30]	validation_0-mlogloss:0.73001
# [31]	validation_0-mlogloss:0.72589
# [32]	validation_0-mlogloss:0.72191
# [33]	validation_0-mlogloss:0.71815
# [34]	validation_0-mlogloss:0.71458
# [35]	validation_0-mlogloss:0.71117
# [36]	validation_0-mlogloss:0.70794
# [37]	validation_0-mlogloss:0.70479
# [38]	validation_0-mlogloss:0.70180
# [39]	validation_0-mlogloss:0.69883
# [40]	validation_0-mlogloss:0.69601
# [41]	validation_0-mlogloss:0.69330
# [42]	validation_0-mlogloss:0.69081
# [43]	validation_0-mlogloss:0.68853
# [44]	validation_0-mlogloss:0.68618
# [45]	validation_0-mlogloss:0.68396
# [46]	validation_0-mlogloss:0.68182
# [47]	validation_0-mlogloss:0.67982
# [48]	validation_0-mlogloss:0.67791
# [49]	validation_0-mlogloss:0.67605
# [50]	validation_0-mlogloss:0.67431
# [51]	validation_0-mlogloss:0.67262
# [52]	validation_0-mlogloss:0.67092
# [53]	validation_0-mlogloss:0.66916
# [54]	validation_0-mlogloss:0.66761
# [55]	validation_0-mlogloss:0.66599
# [56]	validation_0-mlogloss:0.66447
# [57]	validation_0-mlogloss:0.66290
# [58]	validation_0-mlogloss:0.66142
# [59]	validation_0-mlogloss:0.66007
# [60]	validation_0-mlogloss:0.65881
# [61]	validation_0-mlogloss:0.65746
# [62]	validation_0-mlogloss:0.65626
# [63]	validation_0-mlogloss:0.65509
# [64]	validation_0-mlogloss:0.65403
# [65]	validation_0-mlogloss:0.65303
# [66]	validation_0-mlogloss:0.65196
# [67]	validation_0-mlogloss:0.65089
# [68]	validation_0-mlogloss:0.64991
# [69]	validation_0-mlogloss:0.64894
# [70]	validation_0-mlogloss:0.64794
# [71]	validation_0-mlogloss:0.64698
# [72]	validation_0-mlogloss:0.64613
# [73]	validation_0-mlogloss:0.64525
# [74]	validation_0-mlogloss:0.64440
# [75]	validation_0-mlogloss:0.64362
# [76]	validation_0-mlogloss:0.64275
# [77]	validation_0-mlogloss:0.64198
# [78]	validation_0-mlogloss:0.64132
# [79]	validation_0-mlogloss:0.64059
# [80]	validation_0-mlogloss:0.63975
# [81]	validation_0-mlogloss:0.63902
# [82]	validation_0-mlogloss:0.63823
# [83]	validation_0-mlogloss:0.63758
# [84]	validation_0-mlogloss:0.63690
# [85]	validation_0-mlogloss:0.63623
# [86]	validation_0-mlogloss:0.63546
# [87]	validation_0-mlogloss:0.63481
# [88]	validation_0-mlogloss:0.63389
# [89]	validation_0-mlogloss:0.63314
# [90]	validation_0-mlogloss:0.63253
# [91]	validation_0-mlogloss:0.63159
# [92]	validation_0-mlogloss:0.63080
# [93]	validation_0-mlogloss:0.63002
# [94]	validation_0-mlogloss:0.62943
# [95]	validation_0-mlogloss:0.62875
# [96]	validation_0-mlogloss:0.62808
# [97]	validation_0-mlogloss:0.62758
# [98]	validation_0-mlogloss:0.62700
# [99]	validation_0-mlogloss:0.62625
# [100]	validation_0-mlogloss:0.62568
# [101]	validation_0-mlogloss:0.62510
# [102]	validation_0-mlogloss:0.62456
# [103]	validation_0-mlogloss:0.62380
# [104]	validation_0-mlogloss:0.62329
# [105]	validation_0-mlogloss:0.62280
# [106]	validation_0-mlogloss:0.62232
# [107]	validation_0-mlogloss:0.62182
# [108]	validation_0-mlogloss:0.62134
# [109]	validation_0-mlogloss:0.62086
# [110]	validation_0-mlogloss:0.62044
# [111]	validation_0-mlogloss:0.61979
# [112]	validation_0-mlogloss:0.61931
# [113]	validation_0-mlogloss:0.61891
# [114]	validation_0-mlogloss:0.61849
# [115]	validation_0-mlogloss:0.61804
# [116]	validation_0-mlogloss:0.61759
# [117]	validation_0-mlogloss:0.61715
# [118]	validation_0-mlogloss:0.61668
# [119]	validation_0-mlogloss:0.61625
# [120]	validation_0-mlogloss:0.61580
# [121]	validation_0-mlogloss:0.61532
# [122]	validation_0-mlogloss:0.61491
# [123]	validation_0-mlogloss:0.61451
# [124]	validation_0-mlogloss:0.61422
# [125]	validation_0-mlogloss:0.61377
# [126]	validation_0-mlogloss:0.61350
# [127]	validation_0-mlogloss:0.61315
# [128]	validation_0-mlogloss:0.61280
# [129]	validation_0-mlogloss:0.61235
# [130]	validation_0-mlogloss:0.61204
# [131]	validation_0-mlogloss:0.61177
# [132]	validation_0-mlogloss:0.61146
# [133]	validation_0-mlogloss:0.61103
# [134]	validation_0-mlogloss:0.61070
# [135]	validation_0-mlogloss:0.61043
# [136]	validation_0-mlogloss:0.61004
# [137]	validation_0-mlogloss:0.60974
# [138]	validation_0-mlogloss:0.60947
# [139]	validation_0-mlogloss:0.60917
# [140]	validation_0-mlogloss:0.60874
# [141]	validation_0-mlogloss:0.60849
# [142]	validation_0-mlogloss:0.60815
# [143]	validation_0-mlogloss:0.60788
# [144]	validation_0-mlogloss:0.60769
# [145]	validation_0-mlogloss:0.60716
# [146]	validation_0-mlogloss:0.60689
# [147]	validation_0-mlogloss:0.60666
# [148]	validation_0-mlogloss:0.60646
# [149]	validation_0-mlogloss:0.60614
# [150]	validation_0-mlogloss:0.60591
# [151]	validation_0-mlogloss:0.60565
# [152]	validation_0-mlogloss:0.60535
# [153]	validation_0-mlogloss:0.60505
# [154]	validation_0-mlogloss:0.60487
# [155]	validation_0-mlogloss:0.60462
# [156]	validation_0-mlogloss:0.60441
# [157]	validation_0-mlogloss:0.60420
# [158]	validation_0-mlogloss:0.60398
# [159]	validation_0-mlogloss:0.60365
# [160]	validation_0-mlogloss:0.60342
# [161]	validation_0-mlogloss:0.60325
# [162]	validation_0-mlogloss:0.60309
# [163]	validation_0-mlogloss:0.60277
# [164]	validation_0-mlogloss:0.60255
# [165]	validation_0-mlogloss:0.60232
# [166]	validation_0-mlogloss:0.60208
# [167]	validation_0-mlogloss:0.60190
# [168]	validation_0-mlogloss:0.60172
# [169]	validation_0-mlogloss:0.60153
# [170]	validation_0-mlogloss:0.60134
# [171]	validation_0-mlogloss:0.60120
# [172]	validation_0-mlogloss:0.60094
# [173]	validation_0-mlogloss:0.60085
# [174]	validation_0-mlogloss:0.60066
# [175]	validation_0-mlogloss:0.60046
# [176]	validation_0-mlogloss:0.60031
# [177]	validation_0-mlogloss:0.60019
# [178]	validation_0-mlogloss:0.59998
# [179]	validation_0-mlogloss:0.59989
# [180]	validation_0-mlogloss:0.59973
# [181]	validation_0-mlogloss:0.59939
# [182]	validation_0-mlogloss:0.59914
# [183]	validation_0-mlogloss:0.59898
# [184]	validation_0-mlogloss:0.59884
# [185]	validation_0-mlogloss:0.59874
# [186]	validation_0-mlogloss:0.59859
# [187]	validation_0-mlogloss:0.59850
# [188]	validation_0-mlogloss:0.59827
# [189]	validation_0-mlogloss:0.59803
# [190]	validation_0-mlogloss:0.59791
# [191]	validation_0-mlogloss:0.59776
# [192]	validation_0-mlogloss:0.59762
# [193]	validation_0-mlogloss:0.59740
# [194]	validation_0-mlogloss:0.59727
# [195]	validation_0-mlogloss:0.59707
# [196]	validation_0-mlogloss:0.59698
# [197]	validation_0-mlogloss:0.59681
# [198]	validation_0-mlogloss:0.59656
# [199]	validation_0-mlogloss:0.59637
# [200]	validation_0-mlogloss:0.59625
# [201]	validation_0-mlogloss:0.59604
# [202]	validation_0-mlogloss:0.59590
# [203]	validation_0-mlogloss:0.59574
# [204]	validation_0-mlogloss:0.59563
# [205]	validation_0-mlogloss:0.59540
# [206]	validation_0-mlogloss:0.59525
# [207]	validation_0-mlogloss:0.59508
# [208]	validation_0-mlogloss:0.59497
# [209]	validation_0-mlogloss:0.59490
# [210]	validation_0-mlogloss:0.59484
# [211]	validation_0-mlogloss:0.59464
# [212]	validation_0-mlogloss:0.59444
# [213]	validation_0-mlogloss:0.59422
# [214]	validation_0-mlogloss:0.59412
# [215]	validation_0-mlogloss:0.59388
# [216]	validation_0-mlogloss:0.59372
# [217]	validation_0-mlogloss:0.59354
# [218]	validation_0-mlogloss:0.59332
# [219]	validation_0-mlogloss:0.59316
# [220]	validation_0-mlogloss:0.59298
# [221]	validation_0-mlogloss:0.59289
# [222]	validation_0-mlogloss:0.59265
# [223]	validation_0-mlogloss:0.59243
# [224]	validation_0-mlogloss:0.59234
# [225]	validation_0-mlogloss:0.59215
# [226]	validation_0-mlogloss:0.59205
# [227]	validation_0-mlogloss:0.59200
# [228]	validation_0-mlogloss:0.59180
# [229]	validation_0-mlogloss:0.59173
# [230]	validation_0-mlogloss:0.59157
# [231]	validation_0-mlogloss:0.59138
# [232]	validation_0-mlogloss:0.59113
# [233]	validation_0-mlogloss:0.59103
# [234]	validation_0-mlogloss:0.59094
# [235]	validation_0-mlogloss:0.59074
# [236]	validation_0-mlogloss:0.59064
# [237]	validation_0-mlogloss:0.59057
# [238]	validation_0-mlogloss:0.59041
# [239]	validation_0-mlogloss:0.59033
# [240]	validation_0-mlogloss:0.59015
# [241]	validation_0-mlogloss:0.59009
# [242]	validation_0-mlogloss:0.58999
# [243]	validation_0-mlogloss:0.58990
# [244]	validation_0-mlogloss:0.58983
# [245]	validation_0-mlogloss:0.58971
# [246]	validation_0-mlogloss:0.58945
# [247]	validation_0-mlogloss:0.58940
# [248]	validation_0-mlogloss:0.58925
# [249]	validation_0-mlogloss:0.58920
# [250]	validation_0-mlogloss:0.58899
# [251]	validation_0-mlogloss:0.58874
# [252]	validation_0-mlogloss:0.58865
# [253]	validation_0-mlogloss:0.58851
# [254]	validation_0-mlogloss:0.58834
# [255]	validation_0-mlogloss:0.58825
# [256]	validation_0-mlogloss:0.58809
# [257]	validation_0-mlogloss:0.58804
# [258]	validation_0-mlogloss:0.58792
# [259]	validation_0-mlogloss:0.58786
# [260]	validation_0-mlogloss:0.58765
# [261]	validation_0-mlogloss:0.58757
# [262]	validation_0-mlogloss:0.58749
# [263]	validation_0-mlogloss:0.58740
# [264]	validation_0-mlogloss:0.58736
# [265]	validation_0-mlogloss:0.58718
# [266]	validation_0-mlogloss:0.58706
# [267]	validation_0-mlogloss:0.58700
# [268]	validation_0-mlogloss:0.58682
# [269]	validation_0-mlogloss:0.58674
# [270]	validation_0-mlogloss:0.58663
# [271]	validation_0-mlogloss:0.58647
# [272]	validation_0-mlogloss:0.58637
# [273]	validation_0-mlogloss:0.58632
# [274]	validation_0-mlogloss:0.58613
# [275]	validation_0-mlogloss:0.58603
# [276]	validation_0-mlogloss:0.58593
# [277]	validation_0-mlogloss:0.58580
# [278]	validation_0-mlogloss:0.58570
# [279]	validation_0-mlogloss:0.58565
# [280]	validation_0-mlogloss:0.58549
# [281]	validation_0-mlogloss:0.58542
# [282]	validation_0-mlogloss:0.58537
# [283]	validation_0-mlogloss:0.58523
# [284]	validation_0-mlogloss:0.58521
# [285]	validation_0-mlogloss:0.58512
# [286]	validation_0-mlogloss:0.58500
# [287]	validation_0-mlogloss:0.58485
# [288]	validation_0-mlogloss:0.58478
# [289]	validation_0-mlogloss:0.58469
# [290]	validation_0-mlogloss:0.58460
# [291]	validation_0-mlogloss:0.58438
# [292]	validation_0-mlogloss:0.58435
# [293]	validation_0-mlogloss:0.58425
# [294]	validation_0-mlogloss:0.58423
# [295]	validation_0-mlogloss:0.58419
# [296]	validation_0-mlogloss:0.58409
# [297]	validation_0-mlogloss:0.58403
# [298]	validation_0-mlogloss:0.58397
# [299]	validation_0-mlogloss:0.58393
# [300]	validation_0-mlogloss:0.58376
# [301]	validation_0-mlogloss:0.58372
# [302]	validation_0-mlogloss:0.58368
# [303]	validation_0-mlogloss:0.58365
# [304]	validation_0-mlogloss:0.58360
# [305]	validation_0-mlogloss:0.58353
# [306]	validation_0-mlogloss:0.58347
# [307]	validation_0-mlogloss:0.58339
# [308]	validation_0-mlogloss:0.58332
# [309]	validation_0-mlogloss:0.58324
# [310]	validation_0-mlogloss:0.58318
# [311]	validation_0-mlogloss:0.58308
# [312]	validation_0-mlogloss:0.58289
# [313]	validation_0-mlogloss:0.58281
# [314]	validation_0-mlogloss:0.58277
# [315]	validation_0-mlogloss:0.58261
# [316]	validation_0-mlogloss:0.58253
# [317]	validation_0-mlogloss:0.58248
# [318]	validation_0-mlogloss:0.58237
# [319]	validation_0-mlogloss:0.58229
# [320]	validation_0-mlogloss:0.58223
# [321]	validation_0-mlogloss:0.58221
# [322]	validation_0-mlogloss:0.58216
# [323]	validation_0-mlogloss:0.58200
# [324]	validation_0-mlogloss:0.58196
# [325]	validation_0-mlogloss:0.58185
# [326]	validation_0-mlogloss:0.58181
# [327]	validation_0-mlogloss:0.58173
# [328]	validation_0-mlogloss:0.58165
# [329]	validation_0-mlogloss:0.58155
# [330]	validation_0-mlogloss:0.58149
# [331]	validation_0-mlogloss:0.58148
# [332]	validation_0-mlogloss:0.58141
# [333]	validation_0-mlogloss:0.58140
# [334]	validation_0-mlogloss:0.58130
# [335]	validation_0-mlogloss:0.58128
# [336]	validation_0-mlogloss:0.58122
# [337]	validation_0-mlogloss:0.58105
# [338]	validation_0-mlogloss:0.58091
# [339]	validation_0-mlogloss:0.58083
# [340]	validation_0-mlogloss:0.58076
# [341]	validation_0-mlogloss:0.58069
# [342]	validation_0-mlogloss:0.58064
# [343]	validation_0-mlogloss:0.58056
# [344]	validation_0-mlogloss:0.58053
# [345]	validation_0-mlogloss:0.58050
# [346]	validation_0-mlogloss:0.58046
# [347]	validation_0-mlogloss:0.58030
# [348]	validation_0-mlogloss:0.58025
# [349]	validation_0-mlogloss:0.58023
# [350]	validation_0-mlogloss:0.58012
# [351]	validation_0-mlogloss:0.58003
# [352]	validation_0-mlogloss:0.57998
# [353]	validation_0-mlogloss:0.57999
# [354]	validation_0-mlogloss:0.57997
# [355]	validation_0-mlogloss:0.57987
# [356]	validation_0-mlogloss:0.57978
# [357]	validation_0-mlogloss:0.57975
# [358]	validation_0-mlogloss:0.57967
# [359]	validation_0-mlogloss:0.57966
# [360]	validation_0-mlogloss:0.57957
# [361]	validation_0-mlogloss:0.57953
# [362]	validation_0-mlogloss:0.57944
# [363]	validation_0-mlogloss:0.57929
# [364]	validation_0-mlogloss:0.57923
# [365]	validation_0-mlogloss:0.57920
# [366]	validation_0-mlogloss:0.57910
# [367]	validation_0-mlogloss:0.57907
# [368]	validation_0-mlogloss:0.57900
# [369]	validation_0-mlogloss:0.57895
# [370]	validation_0-mlogloss:0.57891
# [371]	validation_0-mlogloss:0.57882
# [372]	validation_0-mlogloss:0.57881
# [373]	validation_0-mlogloss:0.57878
# [374]	validation_0-mlogloss:0.57877
# [375]	validation_0-mlogloss:0.57875
# [376]	validation_0-mlogloss:0.57864
# [377]	validation_0-mlogloss:0.57857
# [378]	validation_0-mlogloss:0.57857
# [379]	validation_0-mlogloss:0.57848
# [380]	validation_0-mlogloss:0.57842
# [381]	validation_0-mlogloss:0.57839
# [382]	validation_0-mlogloss:0.57830
# [383]	validation_0-mlogloss:0.57824
# [384]	validation_0-mlogloss:0.57820
# [385]	validation_0-mlogloss:0.57817
# [386]	validation_0-mlogloss:0.57808
# [387]	validation_0-mlogloss:0.57804
# [388]	validation_0-mlogloss:0.57799
# [389]	validation_0-mlogloss:0.57794
# [390]	validation_0-mlogloss:0.57792
# [391]	validation_0-mlogloss:0.57790
# [392]	validation_0-mlogloss:0.57784
# [393]	validation_0-mlogloss:0.57781
# [394]	validation_0-mlogloss:0.57780
# [395]	validation_0-mlogloss:0.57775
# [396]	validation_0-mlogloss:0.57767
# [397]	validation_0-mlogloss:0.57763
# [398]	validation_0-mlogloss:0.57761
# [399]	validation_0-mlogloss:0.57753
# [400]	validation_0-mlogloss:0.57751
# [401]	validation_0-mlogloss:0.57750
# [402]	validation_0-mlogloss:0.57744
# [403]	validation_0-mlogloss:0.57743
# [404]	validation_0-mlogloss:0.57739
# [405]	validation_0-mlogloss:0.57736
# [406]	validation_0-mlogloss:0.57733
# [407]	validation_0-mlogloss:0.57731
# [408]	validation_0-mlogloss:0.57723
# [409]	validation_0-mlogloss:0.57722
# [410]	validation_0-mlogloss:0.57723
# [411]	validation_0-mlogloss:0.57721
# [412]	validation_0-mlogloss:0.57716
# [413]	validation_0-mlogloss:0.57716
# [414]	validation_0-mlogloss:0.57713
# [415]	validation_0-mlogloss:0.57712
# [416]	validation_0-mlogloss:0.57706
# [417]	validation_0-mlogloss:0.57703
# [418]	validation_0-mlogloss:0.57700
# [419]	validation_0-mlogloss:0.57700
# [420]	validation_0-mlogloss:0.57696
# [421]	validation_0-mlogloss:0.57696
# [422]	validation_0-mlogloss:0.57694
# [423]	validation_0-mlogloss:0.57690
# [424]	validation_0-mlogloss:0.57685
# [425]	validation_0-mlogloss:0.57683
# [426]	validation_0-mlogloss:0.57677
# [427]	validation_0-mlogloss:0.57671
# [428]	validation_0-mlogloss:0.57670
# [429]	validation_0-mlogloss:0.57667
# [430]	validation_0-mlogloss:0.57664
# [431]	validation_0-mlogloss:0.57663
# [432]	validation_0-mlogloss:0.57661
# [433]	validation_0-mlogloss:0.57658
# [434]	validation_0-mlogloss:0.57655
# [435]	validation_0-mlogloss:0.57654
# [436]	validation_0-mlogloss:0.57655
# [437]	validation_0-mlogloss:0.57652
# [438]	validation_0-mlogloss:0.57649
# [439]	validation_0-mlogloss:0.57645
# [440]	validation_0-mlogloss:0.57644
# [441]	validation_0-mlogloss:0.57643
# [442]	validation_0-mlogloss:0.57642
# [443]	validation_0-mlogloss:0.57637
# [444]	validation_0-mlogloss:0.57634
# [445]	validation_0-mlogloss:0.57633
# [446]	validation_0-mlogloss:0.57633
# [447]	validation_0-mlogloss:0.57632
# [448]	validation_0-mlogloss:0.57630
# [449]	validation_0-mlogloss:0.57630
# [450]	validation_0-mlogloss:0.57629
# [451]	validation_0-mlogloss:0.57625
# [452]	validation_0-mlogloss:0.57623
# [453]	validation_0-mlogloss:0.57622
# [454]	validation_0-mlogloss:0.57617
# [455]	validation_0-mlogloss:0.57616
# [456]	validation_0-mlogloss:0.57614
# [457]	validation_0-mlogloss:0.57610
# [458]	validation_0-mlogloss:0.57608
# [459]	validation_0-mlogloss:0.57608
# [460]	validation_0-mlogloss:0.57607
# [461]	validation_0-mlogloss:0.57604
# [462]	validation_0-mlogloss:0.57602
# [463]	validation_0-mlogloss:0.57603
# [464]	validation_0-mlogloss:0.57600
# [465]	validation_0-mlogloss:0.57599
# [466]	validation_0-mlogloss:0.57598
# [467]	validation_0-mlogloss:0.57594
# [468]	validation_0-mlogloss:0.57593
# [469]	validation_0-mlogloss:0.57590
# [470]	validation_0-mlogloss:0.57586
# [471]	validation_0-mlogloss:0.57587
# [472]	validation_0-mlogloss:0.57580
# [473]	validation_0-mlogloss:0.57580
# [474]	validation_0-mlogloss:0.57579
# [475]	validation_0-mlogloss:0.57573
# [476]	validation_0-mlogloss:0.57571
# [477]	validation_0-mlogloss:0.57571
# [478]	validation_0-mlogloss:0.57569
# [479]	validation_0-mlogloss:0.57567
# [480]	validation_0-mlogloss:0.57562
# [481]	validation_0-mlogloss:0.57562
# [482]	validation_0-mlogloss:0.57562
# [483]	validation_0-mlogloss:0.57560
# [484]	validation_0-mlogloss:0.57561
# [485]	validation_0-mlogloss:0.57557
# [486]	validation_0-mlogloss:0.57558
# [487]	validation_0-mlogloss:0.57556
# [488]	validation_0-mlogloss:0.57553
# [489]	validation_0-mlogloss:0.57553
# [490]	validation_0-mlogloss:0.57553
# [491]	validation_0-mlogloss:0.57553
# [492]	validation_0-mlogloss:0.57552
# [493]	validation_0-mlogloss:0.57552
# [494]	validation_0-mlogloss:0.57551
# [495]	validation_0-mlogloss:0.57552
# [496]	validation_0-mlogloss:0.57549
# [497]	validation_0-mlogloss:0.57548
# [498]	validation_0-mlogloss:0.57546
# [499]	validation_0-mlogloss:0.57544
# [500]	validation_0-mlogloss:0.57542
# [501]	validation_0-mlogloss:0.57541
# [502]	validation_0-mlogloss:0.57542
# [503]	validation_0-mlogloss:0.57536
# [504]	validation_0-mlogloss:0.57536
# [505]	validation_0-mlogloss:0.57532
# [506]	validation_0-mlogloss:0.57531
# [507]	validation_0-mlogloss:0.57530
# [508]	validation_0-mlogloss:0.57527
# [509]	validation_0-mlogloss:0.57525
# [510]	validation_0-mlogloss:0.57522
# [511]	validation_0-mlogloss:0.57521
# [512]	validation_0-mlogloss:0.57522
# [513]	validation_0-mlogloss:0.57521
# [514]	validation_0-mlogloss:0.57520
# [515]	validation_0-mlogloss:0.57521
# [516]	validation_0-mlogloss:0.57521
# [517]	validation_0-mlogloss:0.57519
# [518]	validation_0-mlogloss:0.57521
# [519]	validation_0-mlogloss:0.57521
# [520]	validation_0-mlogloss:0.57520
# [521]	validation_0-mlogloss:0.57520
# [522]	validation_0-mlogloss:0.57519
# [523]	validation_0-mlogloss:0.57519
# [524]	validation_0-mlogloss:0.57518
# [525]	validation_0-mlogloss:0.57516
# [526]	validation_0-mlogloss:0.57516
# [527]	validation_0-mlogloss:0.57515
# [528]	validation_0-mlogloss:0.57516
# [529]	validation_0-mlogloss:0.57515
# [530]	validation_0-mlogloss:0.57514
# [531]	validation_0-mlogloss:0.57513
# [532]	validation_0-mlogloss:0.57513
# [533]	validation_0-mlogloss:0.57513
# [534]	validation_0-mlogloss:0.57512
# [535]	validation_0-mlogloss:0.57514
# [536]	validation_0-mlogloss:0.57512
# [537]	validation_0-mlogloss:0.57512
# [538]	validation_0-mlogloss:0.57513
# [539]	validation_0-mlogloss:0.57512
# [540]	validation_0-mlogloss:0.57513
# [541]	validation_0-mlogloss:0.57512
# [542]	validation_0-mlogloss:0.57513
# [543]	validation_0-mlogloss:0.57512
# [544]	validation_0-mlogloss:0.57512
# [545]	validation_0-mlogloss:0.57513
# [546]	validation_0-mlogloss:0.57511
# [547]	validation_0-mlogloss:0.57511
# [548]	validation_0-mlogloss:0.57510
# [549]	validation_0-mlogloss:0.57510
# [550]	validation_0-mlogloss:0.57509
# [551]	validation_0-mlogloss:0.57509
# [552]	validation_0-mlogloss:0.57509
# [553]	validation_0-mlogloss:0.57511
# [554]	validation_0-mlogloss:0.57510
# [555]	validation_0-mlogloss:0.57508
# [556]	validation_0-mlogloss:0.57510
# [557]	validation_0-mlogloss:0.57509
# [558]	validation_0-mlogloss:0.57511
# [559]	validation_0-mlogloss:0.57510
# [560]	validation_0-mlogloss:0.57510
# [561]	validation_0-mlogloss:0.57509
# [562]	validation_0-mlogloss:0.57509
# [563]	validation_0-mlogloss:0.57510
# [564]	validation_0-mlogloss:0.57507
# [565]	validation_0-mlogloss:0.57507
# [566]	validation_0-mlogloss:0.57509
# [567]	validation_0-mlogloss:0.57507
# [568]	validation_0-mlogloss:0.57502
# [569]	validation_0-mlogloss:0.57500
# [570]	validation_0-mlogloss:0.57498
# [571]	validation_0-mlogloss:0.57495
# [572]	validation_0-mlogloss:0.57495
# [573]	validation_0-mlogloss:0.57495
# ...
# [325]	validation_0-mlogloss:0.57651
# [326]	validation_0-mlogloss:0.57645
# [327]	validation_0-mlogloss:0.57630
# [328]	validation_0-mlogloss:0.57622
# [329]	validation_0-mlogloss:0.57612
# [330]	validation_0-mlogloss:0.57609
# [331]	validation_0-mlogloss:0.57594
# [332]	validation_0-mlogloss:0.57582
# [333]	validation_0-mlogloss:0.57576
# [334]	validation_0-mlogloss:0.57571
# [335]	validation_0-mlogloss:0.57553
# [336]	validation_0-mlogloss:0.57545
# [337]	validation_0-mlogloss:0.57533
# [338]	validation_0-mlogloss:0.57531
# [339]	validation_0-mlogloss:0.57527
# [340]	validation_0-mlogloss:0.57522
# [341]	validation_0-mlogloss:0.57518
# [342]	validation_0-mlogloss:0.57516
# [343]	validation_0-mlogloss:0.57512
# [344]	validation_0-mlogloss:0.57503
# [345]	validation_0-mlogloss:0.57498
# [346]	validation_0-mlogloss:0.57493
# [347]	validation_0-mlogloss:0.57484
# [348]	validation_0-mlogloss:0.57479
# [349]	validation_0-mlogloss:0.57476
# [350]	validation_0-mlogloss:0.57470
# [351]	validation_0-mlogloss:0.57461
# [352]	validation_0-mlogloss:0.57455
# [353]	validation_0-mlogloss:0.57451
# [354]	validation_0-mlogloss:0.57447
# [355]	validation_0-mlogloss:0.57437
# [356]	validation_0-mlogloss:0.57431
# [357]	validation_0-mlogloss:0.57430
# [358]	validation_0-mlogloss:0.57421
# [359]	validation_0-mlogloss:0.57414
# [360]	validation_0-mlogloss:0.57408
# [361]	validation_0-mlogloss:0.57402
# [362]	validation_0-mlogloss:0.57401
# [363]	validation_0-mlogloss:0.57390
# [364]	validation_0-mlogloss:0.57382
# [365]	validation_0-mlogloss:0.57377
# [366]	validation_0-mlogloss:0.57365
# [367]	validation_0-mlogloss:0.57356
# [368]	validation_0-mlogloss:0.57351
# [369]	validation_0-mlogloss:0.57347
# [370]	validation_0-mlogloss:0.57344
# [371]	validation_0-mlogloss:0.57336
# [372]	validation_0-mlogloss:0.57332
# [373]	validation_0-mlogloss:0.57330
# [374]	validation_0-mlogloss:0.57323
# [375]	validation_0-mlogloss:0.57316
# [376]	validation_0-mlogloss:0.57312
# [377]	validation_0-mlogloss:0.57308
# [378]	validation_0-mlogloss:0.57303
# [379]	validation_0-mlogloss:0.57295
# [380]	validation_0-mlogloss:0.57292
# [381]	validation_0-mlogloss:0.57286
# [382]	validation_0-mlogloss:0.57279
# [383]	validation_0-mlogloss:0.57278
# [384]	validation_0-mlogloss:0.57269
# [385]	validation_0-mlogloss:0.57264
# [386]	validation_0-mlogloss:0.57259
# [387]	validation_0-mlogloss:0.57251
# [388]	validation_0-mlogloss:0.57247
# [389]	validation_0-mlogloss:0.57242
# [390]	validation_0-mlogloss:0.57237
# [391]	validation_0-mlogloss:0.57234
# [392]	validation_0-mlogloss:0.57231
# [393]	validation_0-mlogloss:0.57228
# [394]	validation_0-mlogloss:0.57225
# [395]	validation_0-mlogloss:0.57224
# [396]	validation_0-mlogloss:0.57216
# [397]	validation_0-mlogloss:0.57210
# [398]	validation_0-mlogloss:0.57207
# [399]	validation_0-mlogloss:0.57205
# [400]	validation_0-mlogloss:0.57200
# [401]	validation_0-mlogloss:0.57197
# [402]	validation_0-mlogloss:0.57194
# [403]	validation_0-mlogloss:0.57190
# [404]	validation_0-mlogloss:0.57189
# [405]	validation_0-mlogloss:0.57184
# [406]	validation_0-mlogloss:0.57176
# [407]	validation_0-mlogloss:0.57167
# [408]	validation_0-mlogloss:0.57165
# [409]	validation_0-mlogloss:0.57157
# [410]	validation_0-mlogloss:0.57156
# [411]	validation_0-mlogloss:0.57154
# [412]	validation_0-mlogloss:0.57150
# [413]	validation_0-mlogloss:0.57147
# [414]	validation_0-mlogloss:0.57142
# [415]	validation_0-mlogloss:0.57138
# [416]	validation_0-mlogloss:0.57132
# [417]	validation_0-mlogloss:0.57129
# [418]	validation_0-mlogloss:0.57123
# [419]	validation_0-mlogloss:0.57124
# [420]	validation_0-mlogloss:0.57118
# [421]	validation_0-mlogloss:0.57116
# [422]	validation_0-mlogloss:0.57113
# [423]	validation_0-mlogloss:0.57108
# [424]	validation_0-mlogloss:0.57109
# [425]	validation_0-mlogloss:0.57105
# [426]	validation_0-mlogloss:0.57103
# [427]	validation_0-mlogloss:0.57098
# [428]	validation_0-mlogloss:0.57094
# [429]	validation_0-mlogloss:0.57093
# [430]	validation_0-mlogloss:0.57092
# [431]	validation_0-mlogloss:0.57086
# [432]	validation_0-mlogloss:0.57081
# [433]	validation_0-mlogloss:0.57082
# [434]	validation_0-mlogloss:0.57079
# [435]	validation_0-mlogloss:0.57078
# [436]	validation_0-mlogloss:0.57071
# [437]	validation_0-mlogloss:0.57072
# [438]	validation_0-mlogloss:0.57068
# [439]	validation_0-mlogloss:0.57067
# [440]	validation_0-mlogloss:0.57067
# [441]	validation_0-mlogloss:0.57064
# [442]	validation_0-mlogloss:0.57057
# [443]	validation_0-mlogloss:0.57057
# [444]	validation_0-mlogloss:0.57053
# [445]	validation_0-mlogloss:0.57050
# [446]	validation_0-mlogloss:0.57047
# [447]	validation_0-mlogloss:0.57047
# [448]	validation_0-mlogloss:0.57045
# [449]	validation_0-mlogloss:0.57041
# [450]	validation_0-mlogloss:0.57035
# [451]	validation_0-mlogloss:0.57033
# [452]	validation_0-mlogloss:0.57033
# [453]	validation_0-mlogloss:0.57031
# [454]	validation_0-mlogloss:0.57025
# [455]	validation_0-mlogloss:0.57026
# [456]	validation_0-mlogloss:0.57026
# [457]	validation_0-mlogloss:0.57022
# [458]	validation_0-mlogloss:0.57021
# [459]	validation_0-mlogloss:0.57021
# [460]	validation_0-mlogloss:0.57017
# [461]	validation_0-mlogloss:0.57016
# [462]	validation_0-mlogloss:0.57014
# [463]	validation_0-mlogloss:0.57011
# [464]	validation_0-mlogloss:0.57007
# [465]	validation_0-mlogloss:0.57005
# [466]	validation_0-mlogloss:0.57001
# [467]	validation_0-mlogloss:0.56998
# [468]	validation_0-mlogloss:0.56995
# [469]	validation_0-mlogloss:0.56993
# [470]	validation_0-mlogloss:0.56993
# [471]	validation_0-mlogloss:0.56990
# [472]	validation_0-mlogloss:0.56987
# [473]	validation_0-mlogloss:0.56987
# [474]	validation_0-mlogloss:0.56982
# [475]	validation_0-mlogloss:0.56978
# [476]	validation_0-mlogloss:0.56976
# [477]	validation_0-mlogloss:0.56974
# [478]	validation_0-mlogloss:0.56974
# [479]	validation_0-mlogloss:0.56971
# [480]	validation_0-mlogloss:0.56969
# [481]	validation_0-mlogloss:0.56962
# [482]	validation_0-mlogloss:0.56957
# [483]	validation_0-mlogloss:0.56953
# [484]	validation_0-mlogloss:0.56952
# [485]	validation_0-mlogloss:0.56950
# [486]	validation_0-mlogloss:0.56946
# [487]	validation_0-mlogloss:0.56944
# [488]	validation_0-mlogloss:0.56944
# [489]	validation_0-mlogloss:0.56943
# [490]	validation_0-mlogloss:0.56942
# [491]	validation_0-mlogloss:0.56940
# [492]	validation_0-mlogloss:0.56939
# [493]	validation_0-mlogloss:0.56937
# [494]	validation_0-mlogloss:0.56937
# [495]	validation_0-mlogloss:0.56934
# [496]	validation_0-mlogloss:0.56931
# [497]	validation_0-mlogloss:0.56931
# [498]	validation_0-mlogloss:0.56930
# [499]	validation_0-mlogloss:0.56928
# [500]	validation_0-mlogloss:0.56925
# [501]	validation_0-mlogloss:0.56925
# [502]	validation_0-mlogloss:0.56925
# [503]	validation_0-mlogloss:0.56921
# [504]	validation_0-mlogloss:0.56922
# [505]	validation_0-mlogloss:0.56920
# [506]	validation_0-mlogloss:0.56915
# [507]	validation_0-mlogloss:0.56911
# [508]	validation_0-mlogloss:0.56905
# [509]	validation_0-mlogloss:0.56905
# [510]	validation_0-mlogloss:0.56904
# [511]	validation_0-mlogloss:0.56902
# [512]	validation_0-mlogloss:0.56902
# [513]	validation_0-mlogloss:0.56898
# [514]	validation_0-mlogloss:0.56897
# [515]	validation_0-mlogloss:0.56898
# [516]	validation_0-mlogloss:0.56899
# [517]	validation_0-mlogloss:0.56898
# [518]	validation_0-mlogloss:0.56896
# [519]	validation_0-mlogloss:0.56897
# [520]	validation_0-mlogloss:0.56896
# [521]	validation_0-mlogloss:0.56893
# [522]	validation_0-mlogloss:0.56895
# [523]	validation_0-mlogloss:0.56891
# [524]	validation_0-mlogloss:0.56892
# [525]	validation_0-mlogloss:0.56891
# [526]	validation_0-mlogloss:0.56890
# [527]	validation_0-mlogloss:0.56889
# [528]	validation_0-mlogloss:0.56888
# [529]	validation_0-mlogloss:0.56889
# [530]	validation_0-mlogloss:0.56889
# [531]	validation_0-mlogloss:0.56887
# [532]	validation_0-mlogloss:0.56889
# [533]	validation_0-mlogloss:0.56885
# [534]	validation_0-mlogloss:0.56884
# [535]	validation_0-mlogloss:0.56880
# [536]	validation_0-mlogloss:0.56881
# [537]	validation_0-mlogloss:0.56879
# [538]	validation_0-mlogloss:0.56877
# [539]	validation_0-mlogloss:0.56875
# [540]	validation_0-mlogloss:0.56876
# [541]	validation_0-mlogloss:0.56876
# [542]	validation_0-mlogloss:0.56876
# [543]	validation_0-mlogloss:0.56874
# [544]	validation_0-mlogloss:0.56875
# [545]	validation_0-mlogloss:0.56876
# [546]	validation_0-mlogloss:0.56876
# [547]	validation_0-mlogloss:0.56877
# [548]	validation_0-mlogloss:0.56875
# [549]	validation_0-mlogloss:0.56876
# [550]	validation_0-mlogloss:0.56875
# [551]	validation_0-mlogloss:0.56877
# [552]	validation_0-mlogloss:0.56876
# [553]	validation_0-mlogloss:0.56877
# [554]	validation_0-mlogloss:0.56877
# [555]	validation_0-mlogloss:0.56874
# [556]	validation_0-mlogloss:0.56873
# [557]	validation_0-mlogloss:0.56874
# [558]	validation_0-mlogloss:0.56874
# [559]	validation_0-mlogloss:0.56874
# [560]	validation_0-mlogloss:0.56875
# [561]	validation_0-mlogloss:0.56875
# [562]	validation_0-mlogloss:0.56877
# [563]	validation_0-mlogloss:0.56876
# [564]	validation_0-mlogloss:0.56875
# [565]	validation_0-mlogloss:0.56872
# [566]	validation_0-mlogloss:0.56873
# [567]	validation_0-mlogloss:0.56871
# [568]	validation_0-mlogloss:0.56872
# [569]	validation_0-mlogloss:0.56871
# [570]	validation_0-mlogloss:0.56870
# [571]	validation_0-mlogloss:0.56870
# [572]	validation_0-mlogloss:0.56867
# [573]	validation_0-mlogloss:0.56868
# [574]	validation_0-mlogloss:0.56869
# [575]	validation_0-mlogloss:0.56869
# [576]	validation_0-mlogloss:0.56868
# [577]	validation_0-mlogloss:0.56869
# [578]	validation_0-mlogloss:0.56869
# [579]	validation_0-mlogloss:0.56870
# [580]	validation_0-mlogloss:0.56872
# [581]	validation_0-mlogloss:0.56870
# [582]	validation_0-mlogloss:0.56872
# [583]	validation_0-mlogloss:0.56873
# [584]	validation_0-mlogloss:0.56872
# [585]	validation_0-mlogloss:0.56871
# [586]	validation_0-mlogloss:0.56872
# [587]	validation_0-mlogloss:0.56872
# [588]	validation_0-mlogloss:0.56871
# [589]	validation_0-mlogloss:0.56872
# [590]	validation_0-mlogloss:0.56872
# [591]	validation_0-mlogloss:0.56872
# [592]	validation_0-mlogloss:0.56872
# [593]	validation_0-mlogloss:0.56871
# [594]	validation_0-mlogloss:0.56870
# [595]	validation_0-mlogloss:0.56872
# [596]	validation_0-mlogloss:0.56872
# [597]	validation_0-mlogloss:0.56872
# [598]	validation_0-mlogloss:0.56871
# [599]	validation_0-mlogloss:0.56868
# [600]	validation_0-mlogloss:0.56870
# [601]	validation_0-mlogloss:0.56871
# [602]	validation_0-mlogloss:0.56870
# [603]	validation_0-mlogloss:0.56870
# [604]	validation_0-mlogloss:0.56872
# [605]	validation_0-mlogloss:0.56873
# [606]	validation_0-mlogloss:0.56873
# [607]	validation_0-mlogloss:0.56873
# [608]	validation_0-mlogloss:0.56872
# [609]	validation_0-mlogloss:0.56872
# [610]	validation_0-mlogloss:0.56873
# [611]	validation_0-mlogloss:0.56875
# [612]	validation_0-mlogloss:0.56873
# [613]	validation_0-mlogloss:0.56874
# [614]	validation_0-mlogloss:0.56872
# [615]	validation_0-mlogloss:0.56870
# [616]	validation_0-mlogloss:0.56870
# [617]	validation_0-mlogloss:0.56868
# [618]	validation_0-mlogloss:0.56865
# [619]	validation_0-mlogloss:0.56867
# [620]	validation_0-mlogloss:0.56868
# [621]	validation_0-mlogloss:0.56869
# [622]	validation_0-mlogloss:0.56868
# [623]	validation_0-mlogloss:0.56868
# [624]	validation_0-mlogloss:0.56869
# [625]	validation_0-mlogloss:0.56869
# [626]	validation_0-mlogloss:0.56870
# [627]	validation_0-mlogloss:0.56870
# [628]	validation_0-mlogloss:0.56872
# [629]	validation_0-mlogloss:0.56872
# [630]	validation_0-mlogloss:0.56872
# [631]	validation_0-mlogloss:0.56874
# [632]	validation_0-mlogloss:0.56873
# [633]	validation_0-mlogloss:0.56876
# [634]	validation_0-mlogloss:0.56875
# [635]	validation_0-mlogloss:0.56876
# [636]	validation_0-mlogloss:0.56876
# [637]	validation_0-mlogloss:0.56877
# [638]	validation_0-mlogloss:0.56880
# [639]	validation_0-mlogloss:0.56880
# [640]	validation_0-mlogloss:0.56880
# [641]	validation_0-mlogloss:0.56881
# [642]	validation_0-mlogloss:0.56882
# [643]	validation_0-mlogloss:0.56883
# [644]	validation_0-mlogloss:0.56881
# [645]	validation_0-mlogloss:0.56881
# [646]	validation_0-mlogloss:0.56883
# [647]	validation_0-mlogloss:0.56882
# [648]	validation_0-mlogloss:0.56883
# [649]	validation_0-mlogloss:0.56884
# [650]	validation_0-mlogloss:0.56883
# [651]	validation_0-mlogloss:0.56882
# [652]	validation_0-mlogloss:0.56883
# [653]	validation_0-mlogloss:0.56885
# [654]	validation_0-mlogloss:0.56883
# [655]	validation_0-mlogloss:0.56885
# [656]	validation_0-mlogloss:0.56887
# [657]	validation_0-mlogloss:0.56888
# [658]	validation_0-mlogloss:0.56887
# [659]	validation_0-mlogloss:0.56888
# [660]	validation_0-mlogloss:0.56887
# [661]	validation_0-mlogloss:0.56889
# [662]	validation_0-mlogloss:0.56890
# [663]	validation_0-mlogloss:0.56890
# [664]	validation_0-mlogloss:0.56890
# [665]	validation_0-mlogloss:0.56891
# [666]	validation_0-mlogloss:0.56893
# [667]	validation_0-mlogloss:0.56892
# [668]	validation_0-mlogloss:0.56894
# [669]	validation_0-mlogloss:0.56893
# [670]	validation_0-mlogloss:0.56893
# [671]	validation_0-mlogloss:0.56892
# [672]	validation_0-mlogloss:0.56892
# [673]	validation_0-mlogloss:0.56893
# [674]	validation_0-mlogloss:0.56895
# [675]	validation_0-mlogloss:0.56894
# [676]	validation_0-mlogloss:0.56895
# [677]	validation_0-mlogloss:0.56895
# [678]	validation_0-mlogloss:0.56898
# [679]	validation_0-mlogloss:0.56899
# [680]	validation_0-mlogloss:0.56896
# [681]	validation_0-mlogloss:0.56898
# [682]	validation_0-mlogloss:0.56898
# [683]	validation_0-mlogloss:0.56899
# [684]	validation_0-mlogloss:0.56898
# [685]	validation_0-mlogloss:0.56898
# [686]	validation_0-mlogloss:0.56900
# [687]	validation_0-mlogloss:0.56900
# [688]	validation_0-mlogloss:0.56902
# [689]	validation_0-mlogloss:0.56901
# [690]	validation_0-mlogloss:0.56903
# [691]	validation_0-mlogloss:0.56905
# [692]	validation_0-mlogloss:0.56905
# [693]	validation_0-mlogloss:0.56904
# [694]	validation_0-mlogloss:0.56905
# [695]	validation_0-mlogloss:0.56907
# [696]	validation_0-mlogloss:0.56908
# [697]	validation_0-mlogloss:0.56910
# [698]	validation_0-mlogloss:0.56912
# [699]	validation_0-mlogloss:0.56912
# [700]	validation_0-mlogloss:0.56912
# [701]	validation_0-mlogloss:0.56912
# [702]	validation_0-mlogloss:0.56913
# [703]	validation_0-mlogloss:0.56915
# [704]	validation_0-mlogloss:0.56917
# [705]	validation_0-mlogloss:0.56917
# [706]	validation_0-mlogloss:0.56917
# [707]	validation_0-mlogloss:0.56918
# [708]	validation_0-mlogloss:0.56920
# [709]	validation_0-mlogloss:0.56920
# [710]	validation_0-mlogloss:0.56920
# [711]	validation_0-mlogloss:0.56921
# [712]	validation_0-mlogloss:0.56923
# [713]	validation_0-mlogloss:0.56924
# [714]	validation_0-mlogloss:0.56925
# [715]	validation_0-mlogloss:0.56927
# [716]	validation_0-mlogloss:0.56928
# [717]	validation_0-mlogloss:0.56931
# [718]	validation_0-mlogloss:0.56930
# [719]	validation_0-mlogloss:0.56931
# [720]	validation_0-mlogloss:0.56930
# [721]	validation_0-mlogloss:0.56931
# [722]	validation_0-mlogloss:0.56933
# [723]	validation_0-mlogloss:0.56935
# [724]	validation_0-mlogloss:0.56935
# [725]	validation_0-mlogloss:0.56938
# [726]	validation_0-mlogloss:0.56941
# [727]	validation_0-mlogloss:0.56942
# [728]	validation_0-mlogloss:0.56943
# [729]	validation_0-mlogloss:0.56945
# [730]	validation_0-mlogloss:0.56946
# [731]	validation_0-mlogloss:0.56947
# [732]	validation_0-mlogloss:0.56949
# [733]	validation_0-mlogloss:0.56950
# [734]	validation_0-mlogloss:0.56950
# [735]	validation_0-mlogloss:0.56950
# [736]	validation_0-mlogloss:0.56951
# [737]	validation_0-mlogloss:0.56952
# [738]	validation_0-mlogloss:0.56955
# [739]	validation_0-mlogloss:0.56956
# [740]	validation_0-mlogloss:0.56956
# [741]	validation_0-mlogloss:0.56959
# [742]	validation_0-mlogloss:0.56961
# [743]	validation_0-mlogloss:0.56962
# [744]	validation_0-mlogloss:0.56962
# [745]	validation_0-mlogloss:0.56962
# [746]	validation_0-mlogloss:0.56963
# [747]	validation_0-mlogloss:0.56966
# [748]	validation_0-mlogloss:0.56965
# [749]	validation_0-mlogloss:0.56965
# [750]	validation_0-mlogloss:0.56969
# [751]	validation_0-mlogloss:0.56969
# [752]	validation_0-mlogloss:0.56971
# [753]	validation_0-mlogloss:0.56973
# [754]	validation_0-mlogloss:0.56975
# [755]	validation_0-mlogloss:0.56977
# [756]	validation_0-mlogloss:0.56979
# [757]	validation_0-mlogloss:0.56981
# [758]	validation_0-mlogloss:0.56982
# [759]	validation_0-mlogloss:0.56982
# [760]	validation_0-mlogloss:0.56984
# [761]	validation_0-mlogloss:0.56984
# [762]	validation_0-mlogloss:0.56986
# [763]	validation_0-mlogloss:0.56988
# [764]	validation_0-mlogloss:0.56989
# [765]	validation_0-mlogloss:0.56991
# [766]	validation_0-mlogloss:0.56992
# [767]	validation_0-mlogloss:0.56991
# F1-MICRO SCORE:  0.7495395241749808

# %%
x = np.array(train_datai)

models = []
for i in range(5):
    model = xgb.Booster()
    model.load_model(f'models/XGBoost{i}.txt')

    dtrain = xgb.DMatrix(x)
    
    y_pred = model.predict(dtrain)
    
    score  = f1_score(np.array(pd.get_dummies(y)), threshold_arr(y_pred), average='micro')
    print("F1-MICRO SCORE: ", score)
    models.append(model)
# Out:
# F1-MICRO SCORE:  0.8357335543608811
# F1-MICRO SCORE:  0.8376828945399287
# F1-MICRO SCORE:  0.8398202616260106
# F1-MICRO SCORE:  0.8353843615335321
# F1-MICRO SCORE:  0.8384695377224186

# %% [markdown]
# submission

# %%
df = test_datai
x = np.array(df)
dtest = xgb.DMatrix(x)
y_pred = ensemble(models, dtest)
y_pred = y_pred.argmax(axis=1)+1
sub_csv = pd.read_csv("submission_format.csv")
sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("submission.csv", index=False)

# %%
y_pred
# Out:
# array([3, 2, 2, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# # **Catboost**

# %% [markdown]
# training

# %%
# from catboost import CatBoostClassifier

# %%
# y = np.array(train_y["damage_grade"] - 1)
# x = np.array(train_datai)

# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
# for ix, (train_index, test_index) in enumerate(skf.split(x, y)):
#     x_train, x_valid, y_train, y_valid = x[train_index], x[test_index], y[train_index], y[test_index]

#     model = CatBoostClassifier(iterations=10000,
#                                learning_rate=0.1,
#                                depth=10,
#                                loss_function='MultiClass',
#                                task_type="CPU",
#                                random_seed=SEED,
#                                od_type='Iter',
#                                od_wait=1000,
#                                verbose=1000)

#     model.fit(x_train, y_train,
#               eval_set=(x_valid, y_valid),
#               early_stopping_rounds=1000)

#     y_pred = model.predict(x_valid)
#     print("F1-MICRO SCORE: ", f1_score(y_valid, y_pred, average='micro'))
#     model.save_model(f'models/CatBoost{ix}.cbm')

# %%
# x = np.array(train_datai)
# models = []
# for i in range(5):
#     model = CatBoostClassifier()
#     model.load_model(f'models/CatBoost{i}.cbm')

#     y_pred = model.predict(x)
#     score = f1_score(y, y_pred, average='micro')
#     print("F1-MICRO SCORE: ", score)
#     models.append(model)

# %% [markdown]
# submission

# %%
# test_datai

# %%
# df = test_datai
# x = np.array(df)
# model = CatBoostClassifier()
# model.load_model(f'models/CatBoost{0}.cbm')
# y_pred = model.predict(x)
# #y_pred = ensemble(models, x)
# y_pred = y_pred.flatten()+1
# sub_csv = pd.read_csv("submission_format.csv")
# sub_csv["damage_grade"] = y_pred
# sub_csv.to_csv("submission.csv", index=False)

# %%
# y_pred

# %% [markdown]
# # **LightGBM**

# %% [markdown]
# Training

# %%
y = np.array(train_y["damage_grade"]-1)
x = np.array(train_datai)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
for ix, (train_index, test_index) in enumerate(skf.split(x,y)):
    lgb_params = {
        "objective" : "multiclass",
        "num_class":3,
        "metric" : "multi_error",
        "boosting": 'gbdt',
        "max_depth" : -1,
        "num_leaves" : 30,
        "learning_rate" : 0.1,
        "feature_fraction" : 0.5,
        "min_sum_hessian_in_leaf" : 0.1,
        "max_bin":8192,
        "verbosity" : 1,
        "num_threads":6,
        "seed": SEED
    }
    
    x_train, x_valid, y_train, y_valid= x[train_index], x[test_index], y[train_index], y[test_index]

    train_data = lgb.Dataset(x_train, label=y_train)
    valid_data = lgb.Dataset(x_valid, label=y_valid)

    model = lgb.train(lgb_params,
                      train_data,
                      10000,
                      valid_sets = [valid_data],
                      early_stopping_rounds=1000,
                      verbose_eval = 1000)

    y_pred = model.predict(x_valid)
    print("F1-MICRO SCORE: ", f1_score(np.array(pd.get_dummies(y_valid)), threshold_arr(y_pred), average='micro'))
    model.save_model(f'models/LGBM{ix}.txt')
# Out:
# C:\an3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\an3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070568 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129695
# [LightGBM] [Info] Number of data points in the train set: 208480, number of used features: 53
# [LightGBM] [Info] Start training from score -2.339173
# [LightGBM] [Info] Start training from score -0.564028
# [LightGBM] [Info] Start training from score -1.094582
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's multi_error: 0.249957
# [2000]	valid_0's multi_error: 0.248921
# Early stopping, best iteration is:
# [1689]	valid_0's multi_error: 0.248479
# F1-MICRO SCORE:  0.7515205003741295
# C:\an3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\an3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129656
# [LightGBM] [Info] Number of data points in the train set: 208481, number of used features: 54
# [LightGBM] [Info] Start training from score -2.339128
# [LightGBM] [Info] Start training from score -0.564032
# [LightGBM] [Info] Start training from score -1.094586
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's multi_error: 0.25282
# [2000]	valid_0's multi_error: 0.25213
# Early stopping, best iteration is:
# [1936]	valid_0's multi_error: 0.251592
# F1-MICRO SCORE:  0.748407521105142
# C:\an3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\an3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129789
# [LightGBM] [Info] Number of data points in the train set: 208481, number of used features: 53
# [LightGBM] [Info] Start training from score -2.339178
# [LightGBM] [Info] Start training from score -0.564024
# [LightGBM] [Info] Start training from score -1.094586
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's multi_error: 0.248791
# [2000]	valid_0's multi_error: 0.248062
# Early stopping, best iteration is:
# [1754]	valid_0's multi_error: 0.247467
# F1-MICRO SCORE:  0.7525326170376055
# C:\an3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\an3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.068334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129643
# [LightGBM] [Info] Number of data points in the train set: 208481, number of used features: 54
# [LightGBM] [Info] Start training from score -2.339178
# [LightGBM] [Info] Start training from score -0.564032
# [LightGBM] [Info] Start training from score -1.094572
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's multi_error: 0.24906
# [2000]	valid_0's multi_error: 0.248676
# Early stopping, best iteration is:
# [1570]	valid_0's multi_error: 0.248101
# F1-MICRO SCORE:  0.7518994627782042
# C:\an3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\an3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 129728
# [LightGBM] [Info] Number of data points in the train set: 208481, number of used features: 53
# [LightGBM] [Info] Start training from score -2.339178
# [LightGBM] [Info] Start training from score -0.564032
# [LightGBM] [Info] Start training from score -1.094572
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's multi_error: 0.251074
# [2000]	valid_0's multi_error: 0.250748
# Early stopping, best iteration is:
# [1343]	valid_0's multi_error: 0.249482
# F1-MICRO SCORE:  0.7505180353031464

# %%
models = []
for i in range(5):
    model = lgb.Booster(model_file=f'models/LGBM{i}.txt')

    y_pred = model.predict(x)
    score  = f1_score(np.array(pd.get_dummies(y)), threshold_arr(y_pred), average='micro')
    print("F1-MICRO SCORE: ", score)
    models.append(model)
# Out:
# F1-MICRO SCORE:  0.8131127662595309
# F1-MICRO SCORE:  0.8199085958994785
# F1-MICRO SCORE:  0.8157451429580087
# F1-MICRO SCORE:  0.8102117796938616
# F1-MICRO SCORE:  0.8040989865733439

# %% [markdown]
# Submission

# %%
df = test_datai
x = np.array(df)
y_pred = ensemble(models, x)
y_pred = y_pred.argmax(axis=1)+1
sub_csv = pd.read_csv("submission_format.csv")
sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("submission.csv", index=False)

# %%
y_pred
# Out:
# array([3, 2, 2, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# # **Ensemble Method**

# %%
from joblib import dump, load
x = np.array(test_datai)

sum_y_pred = np.zeros((86868, 3))
    
for i in range(5):
    # emsemble XGBooster
    model = xgb.Booster()
    model.load_model(f'models/XGBoost{i}.txt')
    dtrain = xgb.DMatrix(x)
    y_pred = model.predict(dtrain)
    sum_y_pred += y_pred*0.2

    # ensemble random forest
    model =  RandomForestClassifier()
    model = load(f'models/rfc_model{i}.joblib')
    y_pred = model.predict_proba(x)
    sum_y_pred += y_pred*0.1    
    
    # emsemble LightGBM
    model = lgb.Booster(model_file=f'models/LGBM{i}.txt')
    y_pred = model.predict(x)
    sum_y_pred += y_pred*0.7
    
    print(sum_y_pred)

    
y_pred = threshold_arr(sum_y_pred)
y_pred = y_pred.argmax(axis=1)+1
# Out:
# [[0.00222482 0.32459972 0.67317545]
#  [0.00243059 0.91600619 0.08156321]
#  [0.01977066 0.57681565 0.40341371]
#  ...
#  [0.03644223 0.87300147 0.09055629]
#  [0.01058904 0.8828498  0.10656116]
#  [0.41290142 0.55438049 0.0327181 ]]
# [[0.00334643 0.48679637 1.5098572 ]
#  [0.00495091 1.79910431 0.19594478]
#  [0.04257378 1.26491594 0.69251031]
#  ...
#  [0.05333405 1.77194489 0.17472106]
#  [0.01317076 1.73508126 0.25174798]
#  [0.9105141  1.03773982 0.0517461 ]]
# [[0.00413543 0.70239189 2.29347267]
#  [0.00710838 2.71157138 0.28132023]
#  [0.06315915 1.79153972 1.14530117]
#  ...
#  [0.08801278 2.63127844 0.28070879]
#  [0.02039129 2.60311201 0.37649671]
#  [1.59241842 1.34260683 0.06497478]]
# [[0.00583199 0.9902181  3.0039499 ]
#  [0.00981942 3.5922104  0.39797016]
#  [0.08825576 2.34290371 1.56884056]
#  ...
#  [0.11388536 3.50048411 0.38563054]
#  [0.0275291  3.41327711 0.55919382]
#  [2.28552719 1.62771437 0.08675846]]
# [[0.00702012 1.24860255 3.74437732]
#  [0.01150886 4.47475282 0.51373831]
#  [0.11626061 2.91004982 1.9736896 ]
#  ...
#  [0.13724304 4.3533112  0.50944578]
#  [0.03371498 4.23874982 0.72753522]
#  [2.93602243 1.9541843  0.1097933 ]]

# %%
y_pred
# Out:
# array([3, 2, 2, ..., 2, 2, 1], dtype=int64)

# %%
sub_csv = pd.read_csv("submission_format.csv")
sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("submission.csv", index=False)
